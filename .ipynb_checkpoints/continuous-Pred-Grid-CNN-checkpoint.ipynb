#    [ 9.00222063e-01]
#    [ 1.63742352e+00]
#    [-3.48514736e-01]
#    [-5.98964691e-01]
#    [ 4.39353526e-01]
#    [-1.14800644e+00]
#    [-4.49609756e-01]
#    [ 2.91182339e-01]]
#
#   [[ 1.36650503e-02]
#    [ 4.57350016e-02]
#    [ 5.53501308e-01]
#    [ 2.28524160e+00]
#    [-5.14823496e-01]
#    [ 2.13562393e+00]
#    [ 4.80265498e-01]
#    [-2.91322589e+00]
#    [ 1.54030597e+00]
#    [-2.17486665e-01]
#    [ 2.66782224e-01]
#    [-6.16820693e-01]
#    [-8.52014363e-01]
#    [-1.77330032e-01]
#    [ 6.12194836e-02]
#    [-2.50878716e+00]
#    [-6.27375960e-01]
#    [ 8.10387492e-01]
#    [-1.67679393e+00]
#    [-1.31114915e-01]]
#
#   [[ 1.26147401e+00]
#    [ 5.15077949e-01]
#    [-1.02243865e+00]
#    [-7.88602054e-01]
#    [ 2.24214268e+00]
#    [ 1.73498416e+00]
#    [-6.96990490e-01]
#    [-1.25901163e-01]
#    [ 6.12031519e-02]
#    [ 9.63746607e-02]
#    [-1.08559620e+00]
#    [-1.00965452e+00]
#    [ 1.16961092e-01]
#    [-7.01509118e-01]
#    [ 8.11234117e-01]
#    [ 6.34714901e-01]
#    [-2.30404317e-01]
#    [-5.35130858e-01]
#    [-1.60722136e+00]
#    [ 1.17042923e+00]]]]

# %% [markdown]
# # LOAD DATA

# %%
# staticData = load_static_data()
# staticData = transform_to_grid_coordinates(staticData)
# mobileData = load_mobile_sensors()
# mobileData = transform_to_grid_coordinates(mobileData)
# allData = pd.concat([staticData, mobileData], ignore_index=True)
# setIds(staticData)
# setIds(allData)
# allData

# with open("all_data_15_min_50_grid.txt", "rb") as fp:   # Unpickling
#     all_data = pickle.load(fp)
    
with open("all_data_15_min_20_grid.txt", "rb") as fp:   # Unpickling
    all_data = pickle.load(fp)
    
# with open("all_data_15_min_20_grid_2019_small.txt", "rb") as fp:   # Unpickling
#     all_data = pickle.load(fp)

# %%
all_data = all_data[all_data['PM2.5'] > 0.2]
all_data = all_data[all_data['humidity'] < 80]

# %% [markdown]
# # Model Functions

# %%
#TODO add params for activations, num layers, width of layers, optimizer, loss function, learning rate, batch size
def createStationaryModel():
    online_model = tf.keras.Sequential([
        layers.Dense(8, activation=tf.nn.relu, input_shape=[len(constants.CONTINUOUS_TRAINING_FEATURES)]),
        layers.Dense(1)
    ])
    online_optimizer = tf.keras.optimizers.Adam(0.0001)

    online_model.compile(loss='mean_absolute_error',
        optimizer=online_optimizer,
        metrics=['mean_absolute_error', 'mean_squared_error'])
    
#     online_model_w_prev = tf.keras.Sequential([
#         layers.Dense(12, activation=tf.nn.relu, input_shape=[len(constants.CONTINUOUS_TRAINING_FEATURES_W_PREV)]),
#         layers.Dense(16, activation=tf.nn.relu),
# #         layers.Dense(16, activation=tf.nn.relu),
#         layers.Dense(1)
#     ])
#     online_w_prev_optimizer = tf.keras.optimizers.Adam(0.00001)

#     online_model_w_prev.compile(loss='mean_absolute_error',
#         optimizer=online_w_prev_optimizer,
#         metrics=['mean_absolute_error', 'mean_squared_error'])
    
    par = PassiveAggressiveRegressor(C=1, epsilon=0.1, loss='epsilon_insensitive', max_iter=100, random_state=0,tol=1e-3)
    
    return online_model, par

# %%
online_model, par_model = createStationaryModel()

# %%
all_data[all_data['timestepContinuous'] == 2305]
# Out:
# Empty DataFrame
# Columns: [PM1, PM2.5, PM10, temperature, humidity, lat, long, lat_grid, long_grid, hour, minute, timestep, timestepContinuous, commercial, residential, green, primary, tertiary, unclassified, residential/service, pedestrian/cycle/noroad, next_pm_2.5, prev_pm_2.5]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# # Train

# %%
def updateModels(data):
    label = data.pop('next_pm_2.5')
    X = data[constants.CONTINUOUS_TRAINING_FEATURES]
    label = np.array(label)
    
    online_model.fit(
        X, label, batch_size=len(data),
        epochs=20, verbose=0)

    par_model.partial_fit(X, label)
                
def trainNNs(train_data):
    class PrintDot(keras.callbacks.Callback):
        def on_epoch_end(self, epoch, logs):
            if epoch % 100 == 0: print('')
            print('.', end='')
                
    labels = []
    X = pd.DataFrame(columns = constants.CONTINUOUS_TRAINING_FEATURES)
    
    start = int(train_data['timestepContinuous'].min())
    end = int(train_data['timestepContinuous'].max())
    for i in range(start, end):
        cur_data = train_data[train_data['timestepContinuous'] == i]
        #Get list of all coords
        lat_coords = np.array(cur_data['lat_grid'])
        long_coords = np.array(cur_data['long_grid'])
                
        for x, y in zip(lat_coords, long_coords):
            x = int(x)
            y = int(y)
            
            #Check which coords have data next step
            if(grid_labels[i + 1][x][y] != None):
                #Append curData for coords that do have data next step
                new_input = cur_data[(cur_data['lat_grid'] == x) & (cur_data['long_grid'] == y)][constants.CONTINUOUS_TRAINING_FEATURES]
                X = pd.concat([X, new_input])
                #Append grid data to labels
                labels.append(grid_labels[i + 1][x][y])
        
    early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)

    par_model.fit(X, labels)

    history = online_model.fit(
        X, labels, batch_size=16,
        epochs=10, verbose=0, validation_split = .2, callbacks=[ early_stop, PrintDot()])

    plot_history(history)
    hist = pd.DataFrame(history.history)
    display(hist)
    
def trainNNnn(trainData):
    
    class PrintDot(keras.callbacks.Callback):
        def on_epoch_end(self, epoch, logs):
            if epoch % 100 == 0: print('')
            print('.', end='')
                
    
        
    X = trainData[constants.CONTINUOUS_TRAINING_FEATURES]
    labels = trainData.pop('next_pm_2.5')
    early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)

    par_model.fit(X, labels)

    history = online_model.fit(
        X, labels, batch_size=8,
        epochs=2000, verbose=0, validation_split = .2, callbacks=[ early_stop, PrintDot()])

    plot_history(history)
    hist = pd.DataFrame(history.history)
    display(hist)
    
        
def plot_history(history):
    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch

    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Abs Error')
    plt.plot(hist['epoch'], hist['mean_absolute_error'],
           label='Train Error')
    plt.plot(hist['epoch'], hist['val_mean_absolute_error'],
           label = 'Val Error')
    plt.legend()

# %%
train = all_data[all_data['timestepContinuous'] <= 1450]
valid = all_data[(all_data['timestepContinuous'] > 1450)]
# train = all_data[(all_data['timestepContinuous'] < 869) | (all_data['timestepContinuous'] > 1119)]
# valid = all_data[(all_data['timestepContinuous'] >= 869) & (all_data['timestepContinuous'] <= 1119)]
# train = all_data[(all_data['timestepContinuous'] < 97) | (all_data['timestepContinuous'] > 447)]
# valid = all_data[(all_data['timestepContinuous'] >= 97) & (all_data['timestepContinuous'] <= 447)]
# train = all_data[all_data['timestepContinuous'] <= 2300]
# valid = all_data[(all_data['timestepContinuous'] > 2300)]

valid[valid['PM2.5'] < 0.2]

# columns= valid.columns
# stationary_train = pd.DataFrame(columns=columns)
# for coords in constants.STATIC_COORDS_GRID.values():
#     x = int(coords[0])
#     y = int(coords[1])
#     curData = train[(train['lat_grid'] == x) & (train['long_grid'] == y)]
#     stationary_train = stationary_train.append(curData)
    
# train = stationary_train
# Out:
# Empty DataFrame
# Columns: [PM1, PM2.5, PM10, temperature, humidity, lat, long, lat_grid, long_grid, hour, minute, timestep, timestepContinuous, commercial, residential, green, primary, tertiary, unclassified, residential/service, pedestrian/cycle/noroad, next_pm_2.5, prev_pm_2.5]
# Index: []
#
# [0 rows x 23 columns]

# %%
columns= valid.columns
stationary_valid = pd.DataFrame(columns=columns)
for coords in constants.STATIC_COORDS_GRID.values():
    x = int(coords[0])
    y = int(coords[1])
    curData = valid[(valid['lat_grid'] == x) & (valid['long_grid'] == y)]
    stationary_valid = stationary_valid.append(curData)

mobile_valid = pd.DataFrame(columns=columns)
for x in range(constants.GRID_SIZE):
    for y in range(constants.GRID_SIZE):
        if [x,y] not in constants.STATIC_COORDS_GRID.values():
            curData = valid[(valid['lat_grid'] == x) & (valid['long_grid'] == y)]
            mobile_valid = mobile_valid.append(curData)
            
display(mobile_valid.describe()[['PM2.5', 'humidity']])
stationary_valid.describe()[['PM2.5', 'humidity']]
# Out:
#             PM2.5    humidity
# count  287.000000  287.000000
# mean     2.086523   43.723545
# std      1.888312    9.034524
# min      0.464305   21.250000
# 25%      0.932502   37.850000
# 50%      1.644128   40.566668
# 75%      2.369923   55.900002
# max     15.460969   60.327274
#              PM2.5     humidity
# count  1071.000000  1071.000000
# mean      0.579589    58.401371
# std       1.417894    10.723826
# min       0.200803    28.500000
# 25%       0.334111    51.183333
# 50%       0.437500    58.275894
# 75%       0.583907    65.343782
# max      40.217064    79.959948

# %% [markdown]
# # Train Functions

# %%
# trainNNs(train)
trainNNnn(train)
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# .................................................................
#          loss  mean_absolute_error  mean_squared_error  val_loss  \
# 0    1.095825             1.095825            3.279061  0.523264
# 1    0.753397             0.753397            2.985808  0.418031
# 2    0.692584             0.692584            2.976422  0.380431
# 3    0.660887             0.660887            2.888297  0.355286
# 4    0.635984             0.635985            2.774791  0.331935
# 5    0.618753             0.618753            2.686540  0.324866
# 6    0.607934             0.607934            2.610302  0.319517
# 7    0.600390             0.600389            2.543537  0.314019
# 8    0.594639             0.594640            2.488120  0.313731
# 9    0.590098             0.590097            2.445771  0.310326
# 10   0.585988             0.585988            2.406093  0.308774
# 11   0.582412             0.582412            2.358589  0.308100
# 12   0.578904             0.578903            2.322712  0.308960
# 13   0.575612             0.575612            2.293669  0.302485
# 14   0.572628             0.572628            2.260029  0.303529
# 15   0.570228             0.570229            2.228782  0.305117
# 16   0.568047             0.568047            2.206741  0.304813
# 17   0.566122             0.566122            2.189984  0.298015
# 18   0.564299             0.564299            2.164424  0.300241
# 19   0.562683             0.562683            2.148804  0.298711
# 20   0.561063             0.561063            2.133367  0.299403
# 445                 0.250481                0.632286
# 446                 0.252121                0.632691
# 447                 0.252086                0.633323
# 448                 0.252292                0.631940
# 449                 0.251643                0.632126
# 450                 0.252034                0.637085
# 451                 0.248690                0.635410
# 452                 0.251286                0.635690
# 453                 0.252805                0.635515
# 454                 0.252548                0.639291
# 455                 0.252361                0.634143
# 456                 0.250893                0.635359
# 457                 0.253045                0.634814
# 458                 0.251046                0.637338
# 459                 0.252893                0.636323
# 460                 0.252056                0.634811
# 461                 0.249617                0.636375
# 462                 0.251422                0.637712
# 463                 0.252515                0.641123
# 464                 0.251461                0.638596
#
# [465 rows x 6 columns]

# %%
with open("grid_labels_" + str(constants.GRID_SIZE)+ ".txt", "rb") as fp:   # Unpickling
    grid_labels = pickle.load(fp)
    
# with open("grid_labels_" + str(constants.GRID_SIZE)+ "_2019_small.txt", "rb") as fp:   # Unpickling
#     grid_labels = pickle.load(fp)

# %% [markdown]
# # Test Time Functions

# %%
def copy_model(model):
    batch_model = keras.models.clone_model(model)
    batch_model.build((None, len(constants.CONTINUOUS_TRAINING_FEATURES)))
    batch_model.compile(optimizer='adam', loss='mean_absolute_error')
    batch_model.set_weights(model.get_weights())
    
    return batch_model

def predictOneTimestep(data):
    online_pred_matrix = [[None for x in range(constants.GRID_SIZE)] for y in range(constants.GRID_SIZE)]
    batch_pred_matrix = [[None for x in range(constants.GRID_SIZE)] for y in range(constants.GRID_SIZE)]
    par_pred_matrix = [[None for x in range(constants.GRID_SIZE)] for y in range(constants.GRID_SIZE)]
    
    #get each datapoint in df and check coords and place in grid
    if (len(data) > 0):
        for index, row in data.iterrows():
            x = int(row['lat_grid'])
            y = int(row['long_grid'])
            columns = list(row.index)
            
#             if([x,y] in constants.STATIC_COORDS_GRID.values()):
            online_pred, batch_pred, par_pred = predictOneDataPoint(pd.DataFrame(row).transpose())
            online_pred_matrix[x][y] = online_pred
            batch_pred_matrix[x][y] = batch_pred
            par_pred_matrix[x][y] = par_pred

    return online_pred_matrix, batch_pred_matrix, par_pred_matrix


def predictOneDataPoint(X):
    X = np.array(X[constants.CONTINUOUS_TRAINING_FEATURES])
    online_pred = online_model.predict(X)
    batch_pred = batch_model.predict(X)
    par_pred = par_model.predict(X)
    
    return (online_pred[0][0], batch_pred[0][0], par_pred[0])

def interpolate(pred_matrix):

    data = np.array([[x, y, pred_matrix[x][y]] for x in range(constants.GRID_SIZE) for y in range(constants.GRID_SIZE) if pred_matrix[x][y] != None])
    if(len(data) > 0):
        ok = OrdinaryKriging(data[:,0], data[:,1], data[:,2], variogram_model='gaussian', verbose=False, enable_plotting=False)
        gridx = np.arange(0.0, constants.GRID_SIZE, 1)
        gridy = np.arange(0.0, constants.GRID_SIZE, 1)
        z, ss = ok.execute('grid', gridx, gridy)
        return z
    else:
        return pred_matrix
    
def run_cnn(pred_matrix, timestep):
    return cnnModel.predict(pred_matrix, constants.GRID_SIZE, timestep)
    
def get_valid_preds(timestep, online_pred_matrix, batch_pred_matrix, par_pred_matrix):
    labels = []
    online_preds = []
    batch_preds = []
    par_preds = []
    
    for x in range(constants.GRID_SIZE):
        for y in range(constants.GRID_SIZE):
            if(grid_labels[timestep + 1][x][y] != None and [x,y] not in constants.STATIC_COORDS_GRID.values() and grid_labels[timestep + 1][x][y] > 0.2):
                online_preds.append(online_pred_matrix[x][y])
                batch_preds.append(batch_pred_matrix[x][y])
                par_preds.append(par_pred_matrix[x][y])
                labels.append(grid_labels[timestep + 1][x][y])
    
    return (np.array(online_preds), np.array(batch_preds), par_preds, labels)
    

def getFullPredictions(data):
    online_predictions = []
    batch_predictions = []
    ensemble = []
    par_predictions = []
    all_labels = []
    
    flat_raw_online_preds = []
    flat_raw_batch_preds = []
    flat_raw_ensemble_preds = []
    flat_online_preds = []
    flat_batch_preds = []
    flat_par_preds = []
    flat_ensemble_preds = []
    online_errors = []
    batch_errors = []
    online_avg_error = 0
    batch_avg_error = 0
    matrix_pred_list = []
    ok_matrix_pred_list = []
    
    for i in range(int(data['timestepContinuous'].min()), int(data['timestepContinuous'].max()) - 1):
#     for i in range(1017, 1019):
        print(i)
        newData = data[data['timestepContinuous'] == i]
        if(len(newData) > 1):
            online_pred_matrix, batch_pred_matrix, par_pred_matrix = predictOneTimestep(newData)
            

            int_online_pred_matrix = interpolate(online_pred_matrix)
            int_batch_pred_matrix = interpolate(batch_pred_matrix)
            int_par_pred_matrix = interpolate(par_pred_matrix)
            
            ok_matrix_pred_list.append(int_online_pred_matrix)

            int_online_pred_matrix = run_cnn(int_online_pred_matrix, i)
            int_par_pred_matrix = run_cnn(int_par_pred_matrix, i)
            int_batch_pred_matrix = run_cnn(int_batch_pred_matrix, i)
                        
            #Reshape to fit grid
            int_online_pred_matrix = np.array(int_online_pred_matrix).reshape(constants.GRID_SIZE,constants.GRID_SIZE)
            int_batch_pred_matrix = np.array(int_batch_pred_matrix).reshape(constants.GRID_SIZE,constants.GRID_SIZE)
            int_par_pred_matrix = np.array(int_par_pred_matrix).reshape(constants.GRID_SIZE,constants.GRID_SIZE)
            
            raw_online_pred, raw_batch_pred, par_pred, labels = get_valid_preds(i, int_online_pred_matrix, int_batch_pred_matrix, int_par_pred_matrix)
            
            if(math.isnan(online_avg_error) != True):
                online_pred = raw_online_pred + online_avg_error
                batch_pred = raw_batch_pred + batch_avg_error
            else:
                online_pred = raw_online_pred
                batch_pred = raw_batch_pred
                
            flat_online_preds.extend(online_pred)
            flat_batch_preds.extend(batch_pred)
            
            flat_raw_online_preds.extend(raw_online_pred)
            flat_raw_batch_preds.extend(raw_batch_pred)
            flat_par_preds.extend(par_pred)
            all_labels.extend(labels)
                        
            online_error = labels - raw_online_pred
            online_errors.extend(online_error)
            
            batch_error = labels - raw_batch_pred
            batch_errors.extend(batch_error)
            
           
            online_avg_error = np.mean(online_errors)
            batch_avg_error = np.mean(batch_errors)


            raw_ensemble_pred = np.add((.5 * raw_online_pred), (.5 * raw_batch_pred))
            ensemble_pred = np.add((.5 * online_pred), (.5 * batch_pred))
            

            flat_ensemble_preds.extend(ensemble_pred)
            flat_raw_ensemble_preds.extend(raw_ensemble_pred)
            
            matrix_pred_list.append(int_online_pred_matrix)

            updateModels(newData)
    return (flat_online_preds, flat_batch_preds, flat_par_preds, flat_ensemble_preds, all_labels, flat_raw_online_preds, flat_raw_batch_preds, flat_raw_ensemble_preds, ok_matrix_pred_list, matrix_pred_list)

# INFO:tensorflow:Restoring parameters from /tmp/model.ckpt
# INFO:tensorflow:Restoring parameters from /tmp/model.ckpt
# INFO:tensorflow:Restoring parameters from /tmp/model.ckpt
# 1.7707838170787709
# 1.734141393007344
# 1.6591651548510948
# 2.9845536989612493
# 2.981326921562824
# 2.961576253825021
# 17.258855284336395
# 457

# %%
colors = (0,0,0)

# Plot
fig, ax = plt.subplots()
ax.scatter(raw_ensemble_preds, labels, c=colors, alpha=0.32,label='Datapoint')

lims = [
    np.min([0, 0]),  # min of both axes
    np.max([10, 10]),  # max of both axes
]

# now plot both limits against eachother
ax.set_aspect('equal')
ax.set_xlim(lims)
ax.set_ylim(lims)

plt.title('Predicted VS. Real PM2.5 Value in Dataset 2018-A')
plt.xlabel('Spatio-temporal Prediction')
plt.ylabel('Real PM2.5 Value')
ax.plot(lims, lims, 'k-', alpha=0.95, zorder=0, label="Zero Error")
ax.legend()
plt.savefig('corrected_ensemble_errors.pdf')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
learning_rate = [0.0001, 1e-05, 1e-06]
num_cells = [8, 16, 32, 64]
z = [[ 0.126, 0.144, 0.135, 0.137], [0.124, 0.132, 0.137, 0.141], [0.122, 0.131, 0.128, .129]]

ax = sns.heatmap(z,  annot=True, fmt='.3f')
plt.ylabel('Learning Rate')
plt.xlabel('Number of Cells in Each Layer')
plt.title('2 Layer Network')
ax.set_yticklabels(learning_rate)
ax.set_xticklabels(num_cells)
plt.savefig('grid_search_layer_2.png')

# %%
# for i in range(200, 210):
#     print(np.array(matrix[i]))
#     ax = sns.heatmap(np.array(matrix[i]))
#     ax.invert_yaxis()
#     plt.show()
# for i in range(200, 210):
#     ax = sns.heatmap(ok_matrix_pred_list[i])
#     ax.invert_yaxis()
# #     plt.imshow(ok_matrix_pred_list[i], cmap='hot', interpolation='nearest')
#     plt.show()   
ax = sns.heatmap(np.array(matrix[300]))
ax.invert_yaxis()
plt.show()

ax = sns.heatmap(np.array(matrix[0]))
ax.invert_yaxis()
plt.show()

# %%
osm_dir = "/Users/ryanegan/Documents/diss/"
filename = osm_dir + "prediction_sample_grid_" + str(constants.GRID_SIZE) + ".csv"
with open(filename, 'w') as csvfile:
    writer = csv.writer(csvfile, lineterminator='\n')
    writer.writerows(online_preds[300])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-8e39390ea132> in <module>
#       3 with open(filename, 'w') as csvfile:
#       4     writer = csv.writer(csvfile, lineterminator='\n')
# ----> 5     writer.writerows(online_preds[300])
#
# TypeError: writerows() argument must be iterable

# %%
temp_matrix = np.array(matrix).ravel()
np.savetxt("cnn_2019_sample.csv", temp_matrix, delimiter=",")

# %%
def plot_preds(preds, labels):
#     hist = pd.DataFrame(history.history)
#     hist['epoch'] = history.epoch

    x = range(len(preds))
    plt.figure()
    plt.xlabel('Data Point')
    plt.ylabel('PM 2.5')
    plt.plot(x, preds,
           label='Predictions')
    plt.plot(x, labels,
           label = 'True Value')
    plt.ylim([0,10])
    plt.xlim([0, 400])
    plt.legend()
    plt.savefig('corrected_ensemble_preds.pdf')

    plt.show()

plot_preds(ensemble_preds, labels)

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
print(mean_absolute_percentage_error(np.array(raw_online_preds), np.array(labels)))
print(mean_absolute_percentage_error(raw_batch_preds, labels))
print(mean_absolute_percentage_error(raw_ensemble_preds, labels))
print(mean_absolute_percentage_error(par_preds, labels))
# Out:
# 1416.5861182036363
# 2210.4833545014817
# 3204.980328664856
# 2464.016165118019
