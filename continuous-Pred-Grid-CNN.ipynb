# %%
import pandas as pd
import numpy as np
import csv
import math
from sklearn.linear_model import PassiveAggressiveRegressor
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from datetime import datetime, timedelta
from pykrige.ok import OrdinaryKriging
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# import xgboost as xgb

import constants
import model19 as cnnModel
# Out:
# iteration i :  0 valid_date :  20180809
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/ryanegan/Documents/diss/model19.py:97: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# ************************
# iter: 0
# training cost: 820.49963
# valid cost: 45.939064
# ************************
#
#
# ************************
# iter: 1
# training cost: 641.6196
# valid cost: 47.381508
# ************************
#
#
# ************************
# iter: 2
# training cost: 601.15063
# valid cost: 45.050835
# ************************
#
#
# ************************
# iter: 3
# training cost: 597.83575
# valid cost: 46.966026
# ************************
#
#
# ************************
# iter: 4
# training cost: 602.79846
# valid cost: 46.53551
# ************************
#
#
# ************************
# iter: 5
# training cost: 603.68933
# valid cost: 46.620438
# ************************
#
#
# ************************
# iter: 6
# training cost: 605.1836
# valid cost: 49.1147
# ************************
#
#
# ************************
# iter: 7
# training cost: 605.42456
# valid cost: 47.097816
# ************************
#
#
# ************************
# iter: 8
# training cost: 598.46936
# valid cost: 46.78455
# ************************
#
#
# ************************
# iter: 9
# training cost: 595.0163
# valid cost: 47.766556
# ************************
#
#
# ************************
# iter: 10
# training cost: 600.0199
# valid cost: 46.54633
# ************************
#
#
# ************************
# iter: 11
# training cost: 596.58563
# valid cost: 47.201744
# ************************
#
#
# ************************
# iter: 12
# training cost: 597.0353
# valid cost: 45.86003
# ************************
#
#
# ************************
# iter: 13
# training cost: 600.8436
# valid cost: 48.085354
# ************************
#
#
# ************************
# iter: 14
# training cost: 595.315
# valid cost: 46.372437
# ************************
#
#
# ************************
# iter: 15
# training cost: 596.0015
# valid cost: 47.463696
# ************************
#
#
# ************************
# iter: 16
# training cost: 596.8753
# valid cost: 46.73009
# ************************
#
#
# ************************
# iter: 17
# training cost: 598.763
# valid cost: 46.118153
# ************************
#
#
# ************************
# iter: 18
# training cost: 597.8564
# valid cost: 45.50232
# ************************
#
#
# ************************
# iter: 19
# training cost: 599.6356
# valid cost: 46.152767
# ************************
#
#
# ************************
# iter: 20
# training cost: 597.3985
# valid cost: 47.632988
# ************************
#
#
# ************************
# iter: 21
# training cost: 597.5599
# valid cost: 46.78306
# ************************
#
#
# ************************
# iter: 22
# training cost: 594.7151
# valid cost: 47.752747
# ************************
#
#
# ************************
# iter: 23
# training cost: 596.69446
# valid cost: 46.981308
# ************************
#
#
# ************************
# iter: 24
# training cost: 594.56433
# valid cost: 45.935745
# ************************
#
#
# ************************
# iter: 25
# training cost: 600.57983
# valid cost: 47.686752
# ************************
#
#
# ************************
# iter: 26
# training cost: 599.355
# valid cost: 44.987614
# ************************
#
#
# ************************
# iter: 27
# training cost: 603.3621
# valid cost: 47.334194
# ************************
#
#
# ************************
# iter: 28
# training cost: 598.0454
# valid cost: 46.788197
# ************************
#
#
# ************************
# iter: 29
# training cost: 600.3043
# valid cost: 48.243015
# ************************
#
#
# ************************
# iter: 30
# training cost: 598.2425
# valid cost: 45.837555
# ************************
#
#
# ************************
# iter: 31
# training cost: 598.9868
# valid cost: 46.75917
# ************************
#
#
# ************************
# iter: 32
# training cost: 598.7665
# valid cost: 45.825188
# ************************
#
#
# ************************
# iter: 33
# training cost: 595.8956
# valid cost: 48.07185
# ************************
#
#
# ************************
# iter: 34
# training cost: 602.07404
# valid cost: 46.570618
# ************************
#
#
# ************************
# iter: 35
# training cost: 598.0223
# valid cost: 47.639668
# ************************
#
#
# ************************
# iter: 36
# training cost: 596.0327
# valid cost: 46.967216
# ************************
#
#
# ************************
# iter: 37
# training cost: 596.81104
# valid cost: 46.781
# ************************
#
#
# ************************
# iter: 38
# training cost: 594.55743
# valid cost: 46.28718
# ************************
#
#
# ************************
# iter: 39
# training cost: 597.1598
# valid cost: 46.953915
# ************************
#
#
# ************************
# iter: 40
# training cost: 603.9289
# valid cost: 46.529602
# ************************
#
#
# ************************
# iter: 41
# training cost: 599.7058
# valid cost: 47.3538
# ************************
#
#
# ************************
# iter: 42
# training cost: 598.0897
# valid cost: 46.553974
# ************************
#
#
# ************************
# iter: 43
# training cost: 597.2068
# valid cost: 47.081
# ************************
#
#
# ************************
# iter: 44
# training cost: 597.6053
# valid cost: 45.998676
# ************************
#
#
# ************************
# iter: 45
# training cost: 592.443
# valid cost: 47.38829
# ************************
#
#
# ************************
# iter: 46
# training cost: 596.57556
# valid cost: 46.250114
# ************************
#
#
# ************************
# iter: 47
# training cost: 596.0918
# valid cost: 46.241722
# ************************
#
#
# ************************
# iter: 48
# training cost: 596.24097
# valid cost: 46.18083
# ************************
#
#
# ************************
# iter: 49
# training cost: 599.94
# valid cost: 46.544167
# ************************
#
#
# ************************
# iter: 50
# training cost: 599.0302
# valid cost: 46.812145
# ************************
#
#
# ************************
# iter: 51
# training cost: 599.0879
# valid cost: 47.483555
# ************************
#
#
# ************************
# iter: 52
# training cost: 598.5236
# valid cost: 47.150665
# ************************
#
#
# ************************
# iter: 53
# training cost: 601.13007
# valid cost: 48.7234
# ************************
#
#
# ************************
# iter: 54
# training cost: 600.8807
# valid cost: 46.351303
# ************************
#
#
# ************************
# iter: 55
# training cost: 597.874
# valid cost: 47.153442
# ************************
#
#
# ************************
# iter: 56
# training cost: 596.62164
# valid cost: 46.48301
# ************************
#
#
# ************************
# iter: 57
# training cost: 596.0756
# valid cost: 45.90176
# ************************
#
#
# ************************
# iter: 58
# training cost: 599.4068
# valid cost: 47.031483
# ************************
#
#
# ************************
# iter: 59
# training cost: 595.6704
# valid cost: 47.80407
# ************************
#
#
# ************************
# iter: 60
# training cost: 594.13226
# valid cost: 47.09105
# ************************
#
#
# ************************
# iter: 61
# training cost: 597.2278
# valid cost: 47.337402
# ************************
#
#
# ************************
# iter: 62
# training cost: 601.26355
# valid cost: 47.264908
# ************************
#
#
# ************************
# iter: 63
# training cost: 598.88086
# valid cost: 47.462193
# ************************
#
#
# ************************
# iter: 64
# training cost: 597.5402
# valid cost: 46.118866
# ************************
#
#
# ************************
# iter: 65
# training cost: 593.05505
# valid cost: 45.63287
# ************************
#
#
# ************************
# iter: 66
# training cost: 594.4239
# valid cost: 46.953484
# ************************
#
#
# ************************
# iter: 67
# training cost: 595.75793
# valid cost: 47.32907
# ************************
#
#
# ************************
# iter: 68
# training cost: 592.9645
# valid cost: 46.336834
# ************************
#
#
# ************************
# iter: 69
# training cost: 595.25525
# valid cost: 47.455395
# ************************
#
#
# ************************
# iter: 70
# training cost: 596.6127
# valid cost: 46.306183
# ************************
#
#
# ************************
# iter: 71
# training cost: 594.1305
# valid cost: 47.242905
# ************************
#
#
# ************************
# iter: 72
# training cost: 594.6656
# valid cost: 46.48386
# ************************
#
#
# ************************
# iter: 73
# training cost: 597.23724
# valid cost: 47.789856
# ************************
#
#
# ************************
# iter: 74
# training cost: 599.4216
# valid cost: 46.57235
# ************************
#
#
# ************************
# iter: 75
# training cost: 598.02563
# valid cost: 46.92146
# ************************
#
#
# ************************
# iter: 76
# training cost: 598.96466
# valid cost: 46.992645
# ************************
#
#
# ************************
# iter: 77
# training cost: 599.6292
# valid cost: 47.809498
# ************************
# ************************
# iter: 78
# training cost: 597.51807
# valid cost: 47.52206
# ************************
#
#
# ************************
# iter: 79
# training cost: 596.37494
# valid cost: 47.17437
# ************************
#
#
# ************************
# iter: 80
# training cost: 594.8299
# valid cost: 46.50328
# ************************
#
#
# ************************
# iter: 81
# training cost: 597.5457
# valid cost: 46.604816
# ************************
#
#
# ************************
# iter: 82
# training cost: 596.37213
# valid cost: 47.10282
# ************************
#
#
# ************************
# iter: 83
# training cost: 594.4104
# valid cost: 47.130962
# ************************
#
#
# ************************
# iter: 84
# training cost: 598.3507
# valid cost: 47.353703
# ************************
#
#
# ************************
# iter: 85
# training cost: 594.6573
# valid cost: 47.35213
# ************************
#
#
# ************************
# iter: 86
# training cost: 597.02765
# valid cost: 46.066147
# ************************
#
#
# ************************
# iter: 87
# training cost: 594.783
# valid cost: 47.45132
# ************************
#
#
# ************************
# iter: 88
# training cost: 598.9231
# valid cost: 45.683666
# ************************
#
#
# ************************
# iter: 89
# training cost: 596.7116
# valid cost: 47.32587
# ************************
#
#
# ************************
# iter: 90
# training cost: 600.37103
# valid cost: 46.0162
# ************************
#
#
# ************************
# iter: 91
# training cost: 596.62537
# valid cost: 46.496326
# ************************
#
#
# ************************
# iter: 92
# training cost: 596.5354
# valid cost: 45.65089
# ************************
#
#
# ************************
# iter: 93
# training cost: 596.6728
# valid cost: 46.93174
# ************************
#
#
# ************************
# iter: 94
# training cost: 596.80597
# valid cost: 46.114986
# ************************
#
#
# ************************
# iter: 95
# training cost: 595.7132
# valid cost: 47.82977
# ************************
#
#
# ************************
# iter: 96
# training cost: 594.5143
# valid cost: 47.671413
# ************************
#
#
# ************************
# iter: 97
# training cost: 596.87616
# valid cost: 46.304974
# ************************
#
#
# ************************
# iter: 98
# training cost: 595.51556
# valid cost: 45.933292
# ************************
#
#
# ************************
# iter: 99
# training cost: 596.89526
# valid cost: 47.164875
# ************************
#
#
# ************************
# iter: 100
# training cost: 595.6888
# valid cost: 46.49122
# ************************
#
#
# ************************
# iter: 101
# training cost: 596.6779
# valid cost: 48.188343
# ************************
#
#
# ************************
# iter: 102
# training cost: 595.38074
# valid cost: 46.76409
# ************************
#
#
# ************************
# iter: 103
# training cost: 596.8532
# valid cost: 47.699146
# ************************
#
#
# ************************
# iter: 104
# training cost: 596.9771
# valid cost: 46.63184
# ************************
#
#
# ************************
# iter: 105
# training cost: 592.9537
# valid cost: 47.290802
# ************************
#
#
# ************************
# iter: 106
# training cost: 594.4484
# valid cost: 47.37904
# ************************
#
#
# ************************
# iter: 107
# training cost: 592.287
# valid cost: 46.703808
# ************************
#
#
# ************************
# iter: 108
# training cost: 594.14685
# valid cost: 46.004417
# ************************
#
#
# ************************
# iter: 109
# training cost: 595.7171
# valid cost: 47.08706
# ************************
#
#
# ************************
# iter: 110
# training cost: 596.94904
# valid cost: 46.100296
# ************************
#
#
# ************************
# iter: 111
# training cost: 592.66595
# valid cost: 47.10912
# ************************
#
#
# ************************
# iter: 112
# training cost: 593.3719
# valid cost: 46.370605
# ************************
#
#
# ************************
# iter: 113
# training cost: 594.00433
# valid cost: 47.556408
# ************************
#
#
# ************************
# iter: 114
# training cost: 593.62506
# valid cost: 46.170647
# ************************
#
#
# ************************
# iter: 115
# training cost: 593.93695
# valid cost: 46.44797
# ************************
#
#
# ************************
# iter: 116
# training cost: 597.1791
# valid cost: 45.59883
# ************************
#
#
# ************************
# iter: 117
# training cost: 595.08044
# valid cost: 48.06283
# ************************
#
#
# ************************
# iter: 118
# training cost: 598.68536
# valid cost: 46.552162
# ************************
#
#
# ************************
# iter: 119
# training cost: 597.45734
# valid cost: 47.5733
# ************************
#
#
# ************************
# iter: 120
# training cost: 599.9188
# valid cost: 46.84906
# ************************
#
#
# ************************
# iter: 121
# training cost: 596.74695
# valid cost: 47.720768
# ************************
#
#
# ************************
# iter: 122
# training cost: 596.3235
# valid cost: 45.36534
# ************************
#
#
# ************************
# iter: 123
# training cost: 596.37836
# valid cost: 46.738033
# ************************
#
#
# ************************
# iter: 124
# training cost: 596.362
# valid cost: 46.293365
# ************************
#
#
# ************************
# iter: 125
# training cost: 596.34796
# valid cost: 47.006355
# ************************
#
#
# ************************
# iter: 126
# training cost: 595.8888
# valid cost: 45.97205
# ************************
#
#
# ************************
# iter: 127
# training cost: 594.8356
# valid cost: 47.58226
# ************************
#
#
# ************************
# iter: 128
# training cost: 593.6419
# valid cost: 47.037136
# ************************
#
#
# ************************
# iter: 129
# training cost: 594.74426
# valid cost: 47.1478
# ************************
#
#
# ************************
# iter: 130
# training cost: 594.30194
# valid cost: 47.22753
# ************************
#
#
# ************************
# iter: 131
# training cost: 594.4303
# valid cost: 47.700726
# ************************
#
#
# ************************
# iter: 132
# training cost: 594.607
# valid cost: 46.687126
# ************************
#
#
# ************************
# iter: 133
# training cost: 595.05414
# valid cost: 48.212353
# ************************
#
#
# ************************
# iter: 134
# training cost: 596.5002
# valid cost: 46.155098
# ************************
#
#
# ************************
# iter: 135
# training cost: 596.2469
# valid cost: 47.729084
# ************************
#
#
# ************************
# iter: 136
# training cost: 595.0896
# valid cost: 46.604527
# ************************
#
#
# ************************
# iter: 137
# training cost: 592.644
# valid cost: 48.221943
# ************************
#
#
# ************************
# iter: 138
# training cost: 594.8635
# valid cost: 46.460236
# ************************
#
#
# ************************
# iter: 139
# training cost: 594.56305
# valid cost: 47.314137
# ************************
#
#
# ************************
# iter: 140
# training cost: 593.77295
# valid cost: 46.082405
# ************************
#
#
# ************************
# iter: 141
# training cost: 594.628
# valid cost: 47.167023
# ************************
#
#
# ************************
# iter: 142
# training cost: 593.5572
# valid cost: 46.629982
# ************************
#
#
# ************************
# iter: 143
# training cost: 593.34454
# valid cost: 47.475807
# ************************
#
#
# ************************
# iter: 144
# training cost: 593.75146
# valid cost: 45.69547
# ************************
#
#
# ************************
# iter: 145
# training cost: 592.88934
# valid cost: 47.18322
# ************************
#
#
# ************************
# iter: 146
# training cost: 596.298
# valid cost: 45.69146
# ************************
#
#
# ************************
# iter: 147
# training cost: 598.1243
# valid cost: 47.00545
# ************************
#
#
# ************************
# iter: 148
# training cost: 598.8327
# valid cost: 46.73694
# ************************
#
#
# ************************
# iter: 149
# training cost: 595.2165
# valid cost: 48.52884
# ************************
#
#
# ************************
# iter: 150
# training cost: 595.90405
# valid cost: 45.840073
# ************************
#
#
# ************************
# iter: 151
# training cost: 596.0127
# valid cost: 46.937332
# ************************
#
#
# ************************
# iter: 152
# training cost: 593.98737
# valid cost: 46.547638
# ************************
#
#
# ************************
# iter: 153
# training cost: 595.44275
# valid cost: 46.147728
# ************************
#
#
# ************************
# iter: 154
# training cost: 597.52545
# valid cost: 46.001324
# ************************
#
#
# ************************
# iter: 155
# training cost: 594.0721
# valid cost: 47.054695
# ************************
# ************************
# iter: 156
# training cost: 593.95245
# valid cost: 47.15315
# ************************
#
#
# ************************
# iter: 157
# training cost: 592.7667
# valid cost: 46.679405
# ************************
#
#
# ************************
# iter: 158
# training cost: 594.0855
# valid cost: 47.186096
# ************************
#
#
# ************************
# iter: 159
# training cost: 597.84766
# valid cost: 46.84002
# ************************
#
#
# ************************
# iter: 160
# training cost: 596.483
# valid cost: 46.4367
# ************************
#
#
# ************************
# iter: 161
# training cost: 597.16016
# valid cost: 47.414364
# ************************
#
#
# ************************
# iter: 162
# training cost: 596.5382
# valid cost: 46.372223
# ************************
#
#
# ************************
# iter: 163
# training cost: 589.8033
# valid cost: 46.75153
# ************************
#
#
# ************************
# iter: 164
# training cost: 595.7056
# valid cost: 47.37326
# ************************
#
#
# ************************
# iter: 165
# training cost: 592.49316
# valid cost: 46.0372
# ************************
#
#
# ************************
# iter: 166
# training cost: 596.3212
# valid cost: 46.38436
# ************************
#
#
# ************************
# iter: 167
# training cost: 589.28253
# valid cost: 47.09756
# ************************
#
#
# ************************
# iter: 168
# training cost: 595.06757
# valid cost: 47.232872
# ************************
#
#
# ************************
# iter: 169
# training cost: 592.95905
# valid cost: 47.12641
# ************************
#
#
# ************************
# iter: 170
# training cost: 593.9486
# valid cost: 46.883907
# ************************
#
#
# ************************
# iter: 171
# training cost: 595.7807
# valid cost: 45.895294
# ************************
#
#
# ************************
# iter: 172
# training cost: 593.07336
# valid cost: 47.79534
# ************************
#
#
# ************************
# iter: 173
# training cost: 594.1679
# valid cost: 46.456417
# ************************
#
#
# ************************
# iter: 174
# training cost: 594.1429
# valid cost: 47.67598
# ************************
#
#
# ************************
# iter: 175
# training cost: 597.8473
# valid cost: 46.4343
# ************************
#
#
# ************************
# iter: 176
# training cost: 600.9696
# valid cost: 47.24732
# ************************
#
#
# ************************
# iter: 177
# training cost: 601.9106
# valid cost: 46.734703
# ************************
#
#
# ************************
# iter: 178
# training cost: 597.2436
# valid cost: 46.265083
# ************************
#
#
# ************************
# iter: 179
# training cost: 595.3716
# valid cost: 46.800144
# ************************
#
#
# ************************
# iter: 180
# training cost: 590.6592
# valid cost: 46.29429
# ************************
#
#
# ************************
# iter: 181
# training cost: 593.2273
# valid cost: 46.287403
# ************************
#
#
# ************************
# iter: 182
# training cost: 593.19995
# valid cost: 46.457424
# ************************
#
#
# ************************
# iter: 183
# training cost: 594.43774
# valid cost: 46.891575
# ************************
#
#
# ************************
# iter: 184
# training cost: 592.60803
# valid cost: 47.193855
# ************************
#
#
# ************************
# iter: 185
# training cost: 593.61444
# valid cost: 46.65813
# ************************
#
#
# ************************
# iter: 186
# training cost: 591.35504
# valid cost: 45.929607
# ************************
#
#
# ************************
# iter: 187
# training cost: 597.3048
# valid cost: 46.0282
# ************************
#
#
# ************************
# iter: 188
# training cost: 592.80853
# valid cost: 47.109447
# ************************
#
#
# ************************
# iter: 189
# training cost: 593.7303
# valid cost: 46.334602
# ************************
#
#
# ************************
# iter: 190
# training cost: 594.9411
# valid cost: 48.66276
# ************************
#
#
# ************************
# iter: 191
# training cost: 597.5562
# valid cost: 45.141838
# ************************
#
#
# ************************
# iter: 192
# training cost: 600.0088
# valid cost: 46.819878
# ************************
#
#
# ************************
# iter: 193
# training cost: 595.8558
# valid cost: 46.276714
# ************************
#
#
# ************************
# iter: 194
# training cost: 595.7233
# valid cost: 47.112904
# ************************
#
#
# ************************
# iter: 195
# training cost: 596.1641
# valid cost: 46.400017
# ************************
#
#
# ************************
# iter: 196
# training cost: 590.6839
# valid cost: 46.20126
# ************************
#
#
# ************************
# iter: 197
# training cost: 593.8126
# valid cost: 46.319805
# ************************
#
#
# ************************
# iter: 198
# training cost: 594.7165
# valid cost: 45.84666
# ************************
#
#
# ************************
# iter: 199
# training cost: 592.4027
# valid cost: 46.085487
# ************************
#
#
# ************************
# iter: 200
# training cost: 592.5957
# valid cost: 47.938427
# ************************
#
#
# ************************
# iter: 201
# training cost: 593.76996
# valid cost: 46.500896
# ************************
#
#
# ************************
# iter: 202
# training cost: 594.7138
# valid cost: 46.99246
# ************************
#
#
# ************************
# iter: 203
# training cost: 595.16174
# valid cost: 46.600933
# ************************
#
#
# ************************
# iter: 204
# training cost: 594.54095
# valid cost: 46.39671
# ************************
#
#
# ************************
# iter: 205
# training cost: 593.61053
# valid cost: 45.675007
# ************************
#
#
# ************************
# iter: 206
# training cost: 595.6115
# valid cost: 46.72403
# ************************
#
#
# ************************
# iter: 207
# training cost: 595.6326
# valid cost: 46.410995
# ************************
#
#
# ************************
# iter: 208
# training cost: 595.35065
# valid cost: 47.077877
# ************************
#
#
# ************************
# iter: 209
# training cost: 599.6837
# valid cost: 45.941864
# ************************
#
#
# ************************
# iter: 210
# training cost: 595.64496
# valid cost: 47.089714
# ************************
#
#
# ************************
# iter: 211
# training cost: 595.0593
# valid cost: 46.98562
# ************************
#
#
# ************************
# iter: 212
# training cost: 596.49554
# valid cost: 46.95153
# ************************
#
#
# ************************
# iter: 213
# training cost: 594.66656
# valid cost: 47.051907
# ************************
#
#
# ************************
# iter: 214
# training cost: 596.30927
# valid cost: 47.634026
# ************************
#
#
# ************************
# iter: 215
# training cost: 594.9435
# valid cost: 46.39444
# ************************
#
#
# ************************
# iter: 216
# training cost: 593.35114
# valid cost: 47.249126
# ************************
#
#
# ************************
# iter: 217
# training cost: 593.50305
# valid cost: 46.41091
# ************************
#
#
# ************************
# iter: 218
# training cost: 595.23895
# valid cost: 47.4227
# ************************
#
#
# ************************
# iter: 219
# training cost: 594.7796
# valid cost: 46.55
# ************************
#
#
# ************************
# iter: 220
# training cost: 592.9544
# valid cost: 47.247925
# ************************
#
#
# ************************
# iter: 221
# training cost: 594.81964
# valid cost: 46.962524
# ************************
#
#
# ************************
# iter: 222
# training cost: 593.3601
# valid cost: 46.444916
# ************************
#
#
# ************************
# iter: 223
# training cost: 594.3702
# valid cost: 46.560234
# ************************
#
#
# ************************
# iter: 224
# training cost: 593.98755
# valid cost: 48.210945
# ************************
#
#
# ************************
# iter: 225
# training cost: 595.4979
# valid cost: 45.697247
# ************************
#
#
# ************************
# iter: 226
# training cost: 593.53687
# valid cost: 45.696686
# ************************
#
#
# ************************
# iter: 227
# training cost: 594.9737
# valid cost: 46.53732
# ************************
#
#
# ************************
# iter: 228
# training cost: 599.2089
# valid cost: 47.979965
# ************************
#
#
# ************************
# iter: 229
# training cost: 596.499
# valid cost: 47.05899
# ************************
#
#
# ************************
# iter: 230
# training cost: 596.5299
# valid cost: 46.163017
# ************************
#
#
# ************************
# iter: 231
# training cost: 594.0211
# valid cost: 46.44518
# ************************
#
#
# ************************
# iter: 232
# training cost: 596.05066
# valid cost: 47.588932
# ************************
# ************************
# iter: 233
# training cost: 594.9467
# valid cost: 47.07024
# ************************
#
#
# ************************
# iter: 234
# training cost: 592.1036
# valid cost: 46.898685
# ************************
#
#
# ************************
# iter: 235
# training cost: 593.5324
# valid cost: 46.357548
# ************************
#
#
# ************************
# iter: 236
# training cost: 591.2816
# valid cost: 47.184193
# ************************
#
#
# ************************
# iter: 237
# training cost: 593.0031
# valid cost: 46.21065
# ************************
#
#
# ************************
# iter: 238
# training cost: 593.03015
# valid cost: 46.997364
# ************************
#
#
# ************************
# iter: 239
# training cost: 595.26056
# valid cost: 46.211823
# ************************
#
#
# ************************
# iter: 240
# training cost: 593.8191
# valid cost: 47.358994
# ************************
#
#
# ************************
# iter: 241
# training cost: 593.8302
# valid cost: 46.350143
# ************************
#
#
# ************************
# iter: 242
# training cost: 595.88965
# valid cost: 48.023636
# ************************
#
#
# ************************
# iter: 243
# training cost: 596.5235
# valid cost: 46.24122
# ************************
#
#
# ************************
# iter: 244
# training cost: 594.84125
# valid cost: 47.308037
# ************************
#
#
# ************************
# iter: 245
# training cost: 596.57336
# valid cost: 46.129536
# ************************
#
#
# ************************
# iter: 246
# training cost: 596.78424
# valid cost: 47.7144
# ************************
#
#
# ************************
# iter: 247
# training cost: 597.591
# valid cost: 46.65195
# ************************
#
#
# ************************
# iter: 248
# training cost: 595.4999
# valid cost: 47.132496
# ************************
#
#
# ************************
# iter: 249
# training cost: 593.39374
# valid cost: 46.063435
# ************************
#
#
# ************************
# iter: 250
# training cost: 594.07635
# valid cost: 48.83775
# ************************
#
#
# ************************
# iter: 251
# training cost: 593.8247
# valid cost: 46.44754
# ************************
#
#
# ************************
# iter: 252
# training cost: 595.0633
# valid cost: 48.021103
# ************************
#
#
# ************************
# iter: 253
# training cost: 593.2309
# valid cost: 46.20936
# ************************
#
#
# ************************
# iter: 254
# training cost: 593.22687
# valid cost: 47.4427
# ************************
#
#
# ************************
# iter: 255
# training cost: 592.7017
# valid cost: 46.29707
# ************************
#
#
# ************************
# iter: 256
# training cost: 593.8349
# valid cost: 47.195602
# ************************
#
#
# ************************
# iter: 257
# training cost: 593.1256
# valid cost: 45.610825
# ************************
#
#
# ************************
# iter: 258
# training cost: 593.68976
# valid cost: 46.86895
# ************************
#
#
# ************************
# iter: 259
# training cost: 593.8392
# valid cost: 46.181286
# ************************
#
#
# ************************
# iter: 260
# training cost: 594.20557
# valid cost: 47.78625
# ************************
#
#
# ************************
# iter: 261
# training cost: 595.4405
# valid cost: 46.165375
# ************************
#
#
# ************************
# iter: 262
# training cost: 594.4185
# valid cost: 47.747196
# ************************
#
#
# ************************
# iter: 263
# training cost: 593.73334
# valid cost: 46.83813
# ************************
#
#
# ************************
# iter: 264
# training cost: 597.13464
# valid cost: 47.065853
# ************************
#
#
# ************************
# iter: 265
# training cost: 596.12067
# valid cost: 46.302547
# ************************
#
#
# ************************
# iter: 266
# training cost: 596.06305
# valid cost: 47.25763
# ************************
#
#
# ************************
# iter: 267
# training cost: 593.7963
# valid cost: 46.782356
# ************************
#
#
# ************************
# iter: 268
# training cost: 593.2552
# valid cost: 47.654358
# ************************
#
#
# ************************
# iter: 269
# training cost: 592.47345
# valid cost: 46.129322
# ************************
#
#
# ************************
# iter: 270
# training cost: 594.6307
# valid cost: 47.017467
# ************************
#
#
# ************************
# iter: 271
# training cost: 596.4733
# valid cost: 46.35532
# ************************
#
#
# ************************
# iter: 272
# training cost: 592.7
# valid cost: 46.656715
# ************************
#
#
# ************************
# iter: 273
# training cost: 593.88184
# valid cost: 46.69779
# ************************
#
#
# ************************
# iter: 274
# training cost: 592.7519
# valid cost: 46.78481
# ************************
#
#
# ************************
# iter: 275
# training cost: 594.3898
# valid cost: 45.899475
# ************************
#
#
# ************************
# iter: 276
# training cost: 593.22253
# valid cost: 46.763786
# ************************
#
#
# ************************
# iter: 277
# training cost: 595.5646
# valid cost: 47.278023
# ************************
#
#
# ************************
# iter: 278
# training cost: 598.0856
# valid cost: 46.84041
# ************************
#
#
# ************************
# iter: 279
# training cost: 595.452
# valid cost: 46.068504
# ************************
#
#
# ************************
# iter: 280
# training cost: 598.6657
# valid cost: 46.325645
# ************************
#
#
# ************************
# iter: 281
# training cost: 597.19507
# valid cost: 46.794785
# ************************
#
#
# ************************
# iter: 282
# training cost: 596.3732
# valid cost: 47.460564
# ************************
#
#
# ************************
# iter: 283
# training cost: 592.82043
# valid cost: 46.753143
# ************************
#
#
# ************************
# iter: 284
# training cost: 594.85455
# valid cost: 47.72274
# ************************
#
#
# ************************
# iter: 285
# training cost: 594.45935
# valid cost: 46.290783
# ************************
#
#
# ************************
# iter: 286
# training cost: 594.13617
# valid cost: 47.094604
# ************************
#
#
# ************************
# iter: 287
# training cost: 594.776
# valid cost: 46.198128
# ************************
#
#
# ************************
# iter: 288
# training cost: 595.35034
# valid cost: 46.645065
# ************************
#
#
# ************************
# iter: 289
# training cost: 595.9482
# valid cost: 46.08916
# ************************
#
#
# ************************
# iter: 290
# training cost: 593.7505
# valid cost: 47.31178
# ************************
#
#
# ************************
# iter: 291
# training cost: 593.759
# valid cost: 46.86119
# ************************
#
#
# ************************
# iter: 292
# training cost: 593.6786
# valid cost: 47.028435
# ************************
#
#
# ************************
# iter: 293
# training cost: 593.80347
# valid cost: 47.025227
# ************************
#
#
# ************************
# iter: 294
# training cost: 593.2885
# valid cost: 46.84677
# ************************
#
#
# ************************
# iter: 295
# training cost: 594.65607
# valid cost: 46.6437
# ************************
#
#
# ************************
# iter: 296
# training cost: 595.102
# valid cost: 46.89788
# ************************
#
#
# ************************
# iter: 297
# training cost: 594.86554
# valid cost: 46.40262
# ************************
#
#
# ************************
# iter: 298
# training cost: 597.0935
# valid cost: 46.811028
# ************************
#
#
# ************************
# iter: 299
# training cost: 594.83594
# valid cost: 45.841106
# ************************
#
#
# ************************
# iter: 300
# training cost: 592.9702
# valid cost: 47.060715
# ************************
#
#
# ************************
# iter: 301
# training cost: 594.85297
# valid cost: 47.102104
# ************************
#
#
# ************************
# iter: 302
# training cost: 593.42334
# valid cost: 47.518
# ************************
#
#
# ************************
# iter: 303
# training cost: 593.184
# valid cost: 46.258476
# ************************
#
#
# ************************
# iter: 304
# training cost: 594.4227
# valid cost: 47.231472
# ************************
#
#
# ************************
# iter: 305
# training cost: 594.3704
# valid cost: 47.572098
# ************************
#
#
# ************************
# iter: 306
# training cost: 594.91003
# valid cost: 47.242504
# ************************
#
#
# ************************
# iter: 307
# training cost: 594.2165
# valid cost: 46.325443
# ************************
#
#
# ************************
# iter: 308
# training cost: 595.4141
# valid cost: 46.467205
# ************************
#
#
# ************************
# iter: 309
# training cost: 594.0042
# valid cost: 46.285217
# ************************
# ************************
# iter: 310
# training cost: 593.92755
# valid cost: 46.298008
# ************************
#
#
# ************************
# iter: 311
# training cost: 598.4254
# valid cost: 46.982903
# ************************
#
#
# ************************
# iter: 312
# training cost: 593.7531
# valid cost: 47.3684
# ************************
#
#
# ************************
# iter: 313
# training cost: 594.47
# valid cost: 47.35429
# ************************
#
#
# ************************
# iter: 314
# training cost: 594.3046
# valid cost: 47.010853
# ************************
#
#
# ************************
# iter: 315
# training cost: 595.5694
# valid cost: 45.585377
# ************************
#
#
# ************************
# iter: 316
# training cost: 594.56506
# valid cost: 46.83846
# ************************
#
#
# ************************
# iter: 317
# training cost: 595.28656
# valid cost: 46.535805
# ************************
#
#
# ************************
# iter: 318
# training cost: 591.349
# valid cost: 46.669167
# ************************
#
#
# ************************
# iter: 319
# training cost: 592.563
# valid cost: 46.847942
# ************************
#
#
# ************************
# iter: 320
# training cost: 592.5294
# valid cost: 47.243263
# ************************
#
#
# ************************
# iter: 321
# training cost: 593.8796
# valid cost: 46.12168
# ************************
#
#
# ************************
# iter: 322
# training cost: 593.64667
# valid cost: 46.767128
# ************************
#
#
# ************************
# iter: 323
# training cost: 593.6774
# valid cost: 45.812172
# ************************
#
#
# ************************
# iter: 324
# training cost: 593.28296
# valid cost: 47.552395
# ************************
#
#
# ************************
# iter: 325
# training cost: 594.3794
# valid cost: 45.830074
# ************************
#
#
# ************************
# iter: 326
# training cost: 598.1688
# valid cost: 46.77085
# ************************
#
#
# ************************
# iter: 327
# training cost: 595.0976
# valid cost: 46.496513
# ************************
#
#
# ************************
# iter: 328
# training cost: 593.7322
# valid cost: 46.79633
# ************************
#
#
# ************************
# iter: 329
# training cost: 593.6371
# valid cost: 46.42435
# ************************
#
#
# ************************
# iter: 330
# training cost: 592.6189
# valid cost: 47.68376
# ************************
#
#
# ************************
# iter: 331
# training cost: 595.6845
# valid cost: 46.898453
# ************************
#
#
# ************************
# iter: 332
# training cost: 594.5556
# valid cost: 47.90516
# ************************
#
#
# ************************
# iter: 333
# training cost: 594.55035
# valid cost: 45.887688
# ************************
#
#
# ************************
# iter: 334
# training cost: 593.1933
# valid cost: 46.945408
# ************************
#
#
# ************************
# iter: 335
# training cost: 594.6054
# valid cost: 47.513756
# ************************
#
#
# ************************
# iter: 336
# training cost: 592.9168
# valid cost: 45.978485
# ************************
#
#
# ************************
# iter: 337
# training cost: 590.3652
# valid cost: 45.954655
# ************************
#
#
# ************************
# iter: 338
# training cost: 593.7567
# valid cost: 46.477913
# ************************
#
#
# ************************
# iter: 339
# training cost: 594.56537
# valid cost: 45.87682
# ************************
#
#
# ************************
# iter: 340
# training cost: 597.636
# valid cost: 47.742584
# ************************
#
#
# ************************
# iter: 341
# training cost: 595.02997
# valid cost: 46.370792
# ************************
#
#
# ************************
# iter: 342
# training cost: 596.16516
# valid cost: 47.830967
# ************************
#
#
# ************************
# iter: 343
# training cost: 594.4927
# valid cost: 46.44317
# ************************
#
#
# ************************
# iter: 344
# training cost: 595.8313
# valid cost: 47.67633
# ************************
#
#
# ************************
# iter: 345
# training cost: 595.5221
# valid cost: 46.382854
# ************************
#
#
# ************************
# iter: 346
# training cost: 593.35913
# valid cost: 46.811222
# ************************
#
#
# ************************
# iter: 347
# training cost: 595.27936
# valid cost: 46.455727
# ************************
#
#
# ************************
# iter: 348
# training cost: 595.09906
# valid cost: 46.5092
# ************************
#
#
# ************************
# iter: 349
# training cost: 592.5651
# valid cost: 47.051334
# ************************
#
#
# ************************
# iter: 350
# training cost: 593.4237
# valid cost: 47.108593
# ************************
#
#
# ************************
# iter: 351
# training cost: 592.5235
# valid cost: 47.41133
# ************************
#
#
# ************************
# iter: 352
# training cost: 593.4402
# valid cost: 46.496033
# ************************
#
#
# ************************
# iter: 353
# training cost: 592.7544
# valid cost: 46.403587
# ************************
#
#
# ************************
# iter: 354
# training cost: 594.7588
# valid cost: 46.529774
# ************************
#
#
# ************************
# iter: 355
# training cost: 594.1868
# valid cost: 46.117157
# ************************
#
#
# ************************
# iter: 356
# training cost: 594.43567
# valid cost: 46.145523
# ************************
#
#
# ************************
# iter: 357
# training cost: 596.8141
# valid cost: 45.690758
# ************************
#
#
# ************************
# iter: 358
# training cost: 592.55
# valid cost: 47.259922
# ************************
#
#
# ************************
# iter: 359
# training cost: 594.9665
# valid cost: 45.851604
# ************************
#
#
# ************************
# iter: 360
# training cost: 593.3515
# valid cost: 47.39321
# ************************
#
#
# ************************
# iter: 361
# training cost: 595.31226
# valid cost: 46.118298
# ************************
#
#
# ************************
# iter: 362
# training cost: 594.12665
# valid cost: 46.453037
# ************************
#
#
# ************************
# iter: 363
# training cost: 593.8935
# valid cost: 47.136787
# ************************
#
#
# ************************
# iter: 364
# training cost: 595.10455
# valid cost: 46.6137
# ************************
#
#
# ************************
# iter: 365
# training cost: 592.2959
# valid cost: 45.73534
# ************************
#
#
# ************************
# iter: 366
# training cost: 594.10065
# valid cost: 46.86183
# ************************
#
#
# ************************
# iter: 367
# training cost: 594.50555
# valid cost: 46.810406
# ************************
#
#
# ************************
# iter: 368
# training cost: 596.94324
# valid cost: 47.4527
# ************************
#
#
# ************************
# iter: 369
# training cost: 597.4211
# valid cost: 46.994675
# ************************
#
#
# ************************
# iter: 370
# training cost: 596.14154
# valid cost: 47.175587
# ************************
#
#
# ************************
# iter: 371
# training cost: 593.87006
# valid cost: 46.321377
# ************************
#
#
# ************************
# iter: 372
# training cost: 593.09283
# valid cost: 46.93836
# ************************
#
#
# ************************
# iter: 373
# training cost: 595.1548
# valid cost: 45.513756
# ************************
#
#
# ************************
# iter: 374
# training cost: 594.65295
# valid cost: 46.445236
# ************************
#
#
# ************************
# iter: 375
# training cost: 592.4579
# valid cost: 46.18375
# ************************
#
#
# ************************
# iter: 376
# training cost: 594.46985
# valid cost: 46.99576
# ************************
#
#
# ************************
# iter: 377
# training cost: 593.4273
# valid cost: 46.969666
# ************************
#
#
# ************************
# iter: 378
# training cost: 597.03674
# valid cost: 47.04795
# ************************
#
#
# ************************
# iter: 379
# training cost: 595.5199
# valid cost: 47.666412
# ************************
#
#
# ************************
# iter: 380
# training cost: 593.9619
# valid cost: 47.21331
# ************************
#
#
# ************************
# iter: 381
# training cost: 597.391
# valid cost: 47.276554
# ************************
#
#
# ************************
# iter: 382
# training cost: 596.2477
# valid cost: 47.016075
# ************************
#
#
# ************************
# iter: 383
# training cost: 592.5534
# valid cost: 46.76547
# ************************
#
#
# ************************
# iter: 384
# training cost: 595.0665
# valid cost: 46.934525
# ************************
#
#
# ************************
# iter: 385
# training cost: 593.9995
# valid cost: 46.238285
# ************************
#
#
# ************************
# iter: 386
# training cost: 594.381
# valid cost: 47.446476
# ************************
#
#
# ************************
# iter: 387
# training cost: 595.019
# valid cost: 46.522392
# ************************
# ************************
# iter: 388
# training cost: 593.8945
# valid cost: 48.50981
# ************************
#
#
# ************************
# iter: 389
# training cost: 595.3964
# valid cost: 45.78171
# ************************
#
#
# ************************
# iter: 390
# training cost: 594.3118
# valid cost: 46.945652
# ************************
#
#
# ************************
# iter: 391
# training cost: 595.2696
# valid cost: 46.1141
# ************************
#
#
# ************************
# iter: 392
# training cost: 595.9656
# valid cost: 46.11792
# ************************
#
#
# ************************
# iter: 393
# training cost: 593.60675
# valid cost: 46.027164
# ************************
#
#
# ************************
# iter: 394
# training cost: 594.1482
# valid cost: 46.65318
# ************************
#
#
# ************************
# iter: 395
# training cost: 595.36926
# valid cost: 47.122505
# ************************
#
#
# ************************
# iter: 396
# training cost: 592.2025
# valid cost: 47.36151
# ************************
#
#
# ************************
# iter: 397
# training cost: 592.70276
# valid cost: 46.272873
# ************************
#
#
# ************************
# iter: 398
# training cost: 593.8639
# valid cost: 46.586197
# ************************
#
#
# ************************
# iter: 399
# training cost: 592.4392
# valid cost: 46.33337
# ************************
#
#
# ************************
# iter: 400
# training cost: 591.80133
# valid cost: 46.507694
# ************************
#
#
# ************************
# iter: 401
# training cost: 594.08795
# valid cost: 47.05464
# ************************
#
#
# ************************
# iter: 402
# training cost: 594.8552
# valid cost: 46.804726
# ************************
#
#
# ************************
# iter: 403
# training cost: 593.3715
# valid cost: 46.76303
# ************************
#
#
# ************************
# iter: 404
# training cost: 593.2051
# valid cost: 47.360527
# ************************
#
#
# ************************
# iter: 405
# training cost: 594.5786
# valid cost: 46.235992
# ************************
#
#
# ************************
# iter: 406
# training cost: 596.53467
# valid cost: 46.82783
# ************************
#
#
# ************************
# iter: 407
# training cost: 596.1224
# valid cost: 45.992455
# ************************
#
#
# ************************
# iter: 408
# training cost: 594.12555
# valid cost: 46.374744
# ************************
#
#
# ************************
# iter: 409
# training cost: 596.2581
# valid cost: 46.33469
# ************************
#
#
# ************************
# iter: 410
# training cost: 593.25275
# valid cost: 48.064377
# ************************
#
#
# ************************
# iter: 411
# training cost: 592.7129
# valid cost: 46.96786
# ************************
#
#
# ************************
# iter: 412
# training cost: 594.4497
# valid cost: 46.36195
# ************************
#
#
# ************************
# iter: 413
# training cost: 591.9283
# valid cost: 46.983307
# ************************
#
#
# ************************
# iter: 414
# training cost: 594.9526
# valid cost: 47.326336
# ************************
#
#
# ************************
# iter: 415
# training cost: 592.57825
# valid cost: 46.177002
# ************************
#
#
# ************************
# iter: 416
# training cost: 594.9186
# valid cost: 46.799843
# ************************
#
#
# ************************
# iter: 417
# training cost: 596.38104
# valid cost: 46.26359
# ************************
#
#
# ************************
# iter: 418
# training cost: 591.93915
# valid cost: 46.481388
# ************************
#
#
# ************************
# iter: 419
# training cost: 595.0406
# valid cost: 46.112022
# ************************
#
#
# ************************
# iter: 420
# training cost: 594.2461
# valid cost: 47.69868
# ************************
#
#
# ************************
# iter: 421
# training cost: 592.5799
# valid cost: 46.722427
# ************************
#
#
# ************************
# iter: 422
# training cost: 592.9145
# valid cost: 47.158577
# ************************
#
#
# ************************
# iter: 423
# training cost: 594.774
# valid cost: 47.19001
# ************************
#
#
# ************************
# iter: 424
# training cost: 594.5887
# valid cost: 46.337856
# ************************
#
#
# ************************
# iter: 425
# training cost: 595.2762
# valid cost: 46.385185
# ************************
#
#
# ************************
# iter: 426
# training cost: 592.6089
# valid cost: 47.885834
# ************************
#
#
# ************************
# iter: 427
# training cost: 596.3521
# valid cost: 46.30672
# ************************
#
#
# ************************
# iter: 428
# training cost: 592.14044
# valid cost: 47.012413
# ************************
#
#
# ************************
# iter: 429
# training cost: 592.42645
# valid cost: 45.7881
# ************************
#
#
# ************************
# iter: 430
# training cost: 594.1044
# valid cost: 47.121002
# ************************
#
#
# ************************
# iter: 431
# training cost: 592.7881
# valid cost: 46.44474
# ************************
#
#
# ************************
# iter: 432
# ...
# iter: 216
# training cost: 631.04956
# valid cost: 9.92211
# ************************
#
#
# ************************
# iter: 217
# training cost: 630.0227
# valid cost: 9.363081
# ************************
#
#
# ************************
# iter: 218
# training cost: 629.6632
# valid cost: 9.520879
# ************************
#
#
# ************************
# iter: 219
# training cost: 632.06226
# valid cost: 8.901607
# ************************
#
#
# ************************
# iter: 220
# training cost: 630.13226
# valid cost: 9.9191885
# ************************
#
#
# ************************
# iter: 221
# training cost: 631.56
# valid cost: 8.491131
# ************************
#
#
# ************************
# iter: 222
# training cost: 633.87213
# valid cost: 10.437561
# ************************
#
#
# ************************
# iter: 223
# training cost: 633.097
# valid cost: 8.41309
# ************************
#
#
# ************************
# iter: 224
# training cost: 635.025
# valid cost: 11.350197
# ************************
#
#
# ************************
# iter: 225
# training cost: 632.52264
# valid cost: 8.076486
# ************************
#
#
# ************************
# iter: 226
# training cost: 634.3906
# valid cost: 10.575996
# ************************
#
#
# ************************
# iter: 227
# training cost: 636.3718
# valid cost: 8.354881
# ************************
#
#
# ************************
# iter: 228
# training cost: 633.79846
# valid cost: 9.709445
# ************************
#
#
# ************************
# iter: 229
# training cost: 632.5848
# valid cost: 9.212033
# ************************
#
#
# ************************
# iter: 230
# training cost: 633.4718
# valid cost: 9.728054
# ************************
#
#
# ************************
# iter: 231
# training cost: 631.19183
# valid cost: 8.957319
# ************************
#
#
# ************************
# iter: 232
# training cost: 629.7816
# valid cost: 9.355932
# ************************
#
#
# ************************
# iter: 233
# training cost: 631.9223
# valid cost: 9.404923
# ************************
# ************************
# iter: 234
# training cost: 629.7033
# valid cost: 9.450568
# ************************
#
#
# ************************
# iter: 235
# training cost: 631.3526
# valid cost: 9.354795
# ************************
#
#
# ************************
# iter: 236
# training cost: 629.20374
# valid cost: 9.8400545
# ************************
#
#
# ************************
# iter: 237
# training cost: 630.96906
# valid cost: 8.829409
# ************************
#
#
# ************************
# iter: 238
# training cost: 631.202
# valid cost: 9.602293
# ************************
#
#
# ************************
# iter: 239
# training cost: 630.322
# valid cost: 9.423566
# ************************
#
#
# ************************
# iter: 240
# training cost: 631.772
# valid cost: 9.307773
# ************************
#
#
# ************************
# iter: 241
# training cost: 630.5556
# valid cost: 9.685956
# ************************
#
#
# ************************
# iter: 242
# training cost: 631.6205
# valid cost: 8.447601
# ************************
#
#
# ************************
# iter: 243
# training cost: 630.151
# valid cost: 10.871761
# ************************
#
#
# ************************
# iter: 244
# training cost: 634.1587
# valid cost: 7.6923447
# ************************
#
#
# ************************
# iter: 245
# training cost: 633.4777
# valid cost: 11.852165
# ************************
#
#
# ************************
# iter: 246
# training cost: 634.9755
# valid cost: 7.677368
# ************************
#
#
# ************************
# iter: 247
# training cost: 638.1728
# valid cost: 11.6704035
# ************************
#
#
# ************************
# iter: 248
# training cost: 636.1619
# valid cost: 8.244373
# ************************
#
#
# ************************
# iter: 249
# training cost: 634.3776
# valid cost: 9.895991
# ************************
#
#
# ************************
# iter: 250
# training cost: 630.65717
# valid cost: 8.561627
# ************************
#
#
# ************************
# iter: 251
# training cost: 631.42834
# valid cost: 9.764084
# ************************
#
#
# ************************
# iter: 252
# training cost: 633.20245
# valid cost: 9.179954
# ************************
#
#
# ************************
# iter: 253
# training cost: 627.7485
# valid cost: 9.684811
# ************************
#
#
# ************************
# iter: 254
# training cost: 632.95013
# valid cost: 9.125918
# ************************
#
#
# ************************
# iter: 255
# training cost: 630.2869
# valid cost: 9.4155245
# ************************
#
#
# ************************
# iter: 256
# training cost: 630.74396
# valid cost: 10.056955
# ************************
#
#
# ************************
# iter: 257
# training cost: 634.8273
# valid cost: 9.14887
# ************************
#
#
# ************************
# iter: 258
# training cost: 629.4801
# valid cost: 9.77088
# ************************
#
#
# ************************
# iter: 259
# training cost: 630.63745
# valid cost: 8.445558
# ************************
#
#
# ************************
# iter: 260
# training cost: 634.42316
# valid cost: 11.019152
# ************************
#
#
# ************************
# iter: 261
# training cost: 634.7833
# valid cost: 7.8392534
# ************************
#
#
# ************************
# iter: 262
# training cost: 633.4205
# valid cost: 10.692265
# ************************
#
#
# ************************
# iter: 263
# training cost: 632.3979
# valid cost: 8.16852
# ************************
#
#
# ************************
# iter: 264
# training cost: 633.1688
# valid cost: 10.099989
# ************************
#
#
# ************************
# iter: 265
# training cost: 631.8756
# valid cost: 8.733048
# ************************
#
#
# ************************
# iter: 266
# training cost: 629.93976
# valid cost: 10.255575
# ************************
#
#
# ************************
# iter: 267
# training cost: 633.0119
# valid cost: 8.68035
# ************************
#
#
# ************************
# iter: 268
# training cost: 629.8128
# valid cost: 9.971557
# ************************
#
#
# ************************
# iter: 269
# training cost: 630.07117
# valid cost: 8.491398
# ************************
#
#
# ************************
# iter: 270
# training cost: 631.5694
# valid cost: 10.331637
# ************************
#
#
# ************************
# iter: 271
# training cost: 632.24335
# valid cost: 8.5918
# ************************
#
#
# ************************
# iter: 272
# training cost: 630.9962
# valid cost: 10.357608
# ************************
#
#
# ************************
# iter: 273
# training cost: 633.415
# valid cost: 8.4740505
# ************************
#
#
# ************************
# iter: 274
# training cost: 632.1447
# valid cost: 10.780991
# ************************
#
#
# ************************
# iter: 275
# training cost: 631.3644
# valid cost: 8.506268
# ************************
#
#
# ************************
# iter: 276
# training cost: 631.3437
# valid cost: 10.3180485
# ************************
#
#
# ************************
# iter: 277
# training cost: 632.6549
# valid cost: 8.831892
# ************************
#
#
# ************************
# iter: 278
# training cost: 628.8745
# valid cost: 9.675663
# ************************
#
#
# ************************
# iter: 279
# training cost: 630.3589
# valid cost: 9.047342
# ************************
#
#
# ************************
# iter: 280
# training cost: 634.28394
# valid cost: 10.255576
# ************************
#
#
# ************************
# iter: 281
# training cost: 631.4933
# valid cost: 8.818879
# ************************
#
#
# ************************
# iter: 282
# training cost: 630.72925
# valid cost: 10.477501
# ************************
#
#
# ************************
# iter: 283
# training cost: 631.4118
# valid cost: 8.45884
# ************************
#
#
# ************************
# iter: 284
# training cost: 631.0537
# valid cost: 10.64469
# ************************
#
#
# ************************
# iter: 285
# training cost: 632.57416
# valid cost: 8.523211
# ************************
#
#
# ************************
# iter: 286
# training cost: 630.5524
# valid cost: 10.780826
# ************************
#
#
# ************************
# iter: 287
# training cost: 634.10724
# valid cost: 8.230543
# ************************
#
#
# ************************
# iter: 288
# training cost: 632.1004
# valid cost: 10.286061
# ************************
#
#
# ************************
# iter: 289
# training cost: 635.96124
# valid cost: 8.598042
# ************************
#
#
# ************************
# iter: 290
# training cost: 636.0577
# valid cost: 11.193062
# ************************
#
#
# ************************
# iter: 291
# training cost: 633.3348
# valid cost: 8.249706
# ************************
#
#
# ************************
# iter: 292
# training cost: 630.14453
# valid cost: 9.861869
# ************************
#
#
# ************************
# iter: 293
# training cost: 632.77277
# valid cost: 8.855846
# ************************
#
#
# ************************
# iter: 294
# training cost: 632.9945
# valid cost: 9.850102
# ************************
#
#
# ************************
# iter: 295
# training cost: 630.96326
# valid cost: 8.934724
# ************************
#
#
# ************************
# iter: 296
# training cost: 630.9323
# valid cost: 9.822823
# ************************
#
#
# ************************
# iter: 297
# training cost: 629.524
# valid cost: 8.6168
# ************************
#
#
# ************************
# iter: 298
# training cost: 631.5066
# valid cost: 9.548307
# ************************
#
#
# ************************
# iter: 299
# training cost: 631.51764
# valid cost: 8.724065
# ************************
#
#
# ************************
# iter: 300
# training cost: 632.86896
# valid cost: 9.946005
# ************************
#
#
# ************************
# iter: 301
# training cost: 630.9557
# valid cost: 8.799999
# ************************
#
#
# ************************
# iter: 302
# training cost: 632.1728
# valid cost: 9.988356
# ************************
#
#
# ************************
# iter: 303
# training cost: 629.53143
# valid cost: 8.147535
# ************************
#
#
# ************************
# iter: 304
# training cost: 632.9551
# valid cost: 11.078134
# ************************
#
#
# ************************
# iter: 305
# training cost: 632.9166
# valid cost: 8.420498
# ************************
#
#
# ************************
# iter: 306
# training cost: 632.56036
# valid cost: 10.552687
# ************************
#
#
# ************************
# iter: 307
# training cost: 631.921
# valid cost: 8.92913
# ************************
#
#
# ************************
# iter: 308
# training cost: 633.65533
# valid cost: 9.786346
# ************************
#
#
# ************************
# iter: 309
# training cost: 632.4462
# valid cost: 8.881023
# ************************
#
#
# ************************
# iter: 310
# training cost: 630.0277
# valid cost: 10.047246
# ************************
#
#
# ************************
# iter: 311
# training cost: 631.6562
# valid cost: 8.441538
# ************************
# ************************
# iter: 312
# training cost: 631.105
# valid cost: 10.120335
# ************************
#
#
# ************************
# iter: 313
# training cost: 632.5887
# valid cost: 8.529792
# ************************
#
#
# ************************
# iter: 314
# training cost: 631.8701
# valid cost: 10.238947
# ************************
#
#
# ************************
# iter: 315
# training cost: 628.9114
# valid cost: 8.335427
# ************************
#
#
# ************************
# iter: 316
# training cost: 634.3205
# valid cost: 11.275486
# ************************
#
#
# ************************
# iter: 317
# training cost: 631.938
# valid cost: 8.026559
# ************************
#
#
# ************************
# iter: 318
# training cost: 632.53754
# valid cost: 10.616911
# ************************
#
#
# ************************
# iter: 319
# training cost: 632.9405
# valid cost: 8.451679
# ************************
#
#
# ************************
# iter: 320
# training cost: 633.40137
# valid cost: 10.436619
# ************************
#
#
# ************************
# iter: 321
# training cost: 633.5287
# valid cost: 8.577097
# ************************
#
#
# ************************
# iter: 322
# training cost: 632.1751
# valid cost: 9.954399
# ************************
#
#
# ************************
# iter: 323
# training cost: 631.78076
# valid cost: 8.656942
# ************************
#
#
# ************************
# iter: 324
# training cost: 633.1792
# valid cost: 10.229559
# ************************
#
#
# ************************
# iter: 325
# training cost: 631.945
# valid cost: 8.519304
# ************************
#
#
# ************************
# iter: 326
# training cost: 632.46735
# valid cost: 10.102806
# ************************
#
#
# ************************
# iter: 327
# training cost: 632.87695
# valid cost: 8.430708
# ************************
#
#
# ************************
# iter: 328
# training cost: 631.0512
# valid cost: 9.936466
# ************************
#
#
# ************************
# iter: 329
# training cost: 631.51086
# valid cost: 8.541168
# ************************
#
#
# ************************
# iter: 330
# training cost: 633.4415
# valid cost: 10.596553
# ************************
#
#
# ************************
# iter: 331
# training cost: 633.1342
# valid cost: 8.747408
# ************************
#
#
# ************************
# iter: 332
# training cost: 632.32806
# valid cost: 10.029717
# ************************
#
#
# ************************
# iter: 333
# training cost: 630.8971
# valid cost: 8.555296
# ************************
#
#
# ************************
# iter: 334
# training cost: 631.1624
# valid cost: 10.240097
# ************************
#
#
# ************************
# iter: 335
# training cost: 632.0723
# valid cost: 8.259226
# ************************
#
#
# ************************
# iter: 336
# training cost: 633.77264
# valid cost: 10.578121
# ************************
#
#
# ************************
# iter: 337
# training cost: 633.96564
# valid cost: 8.3832
# ************************
#
#
# ************************
# iter: 338
# training cost: 631.4327
# valid cost: 10.505957
# ************************
#
#
# ************************
# iter: 339
# training cost: 632.8369
# valid cost: 8.147188
# ************************
#
#
# ************************
# iter: 340
# training cost: 633.7364
# valid cost: 10.6095085
# ************************
#
#
# ************************
# iter: 341
# training cost: 630.6098
# valid cost: 8.757688
# ************************
#
#
# ************************
# iter: 342
# training cost: 631.6257
# valid cost: 10.028126
# ************************
#
#
# ************************
# iter: 343
# training cost: 630.2224
# valid cost: 8.664636
# ************************
#
#
# ************************
# iter: 344
# training cost: 632.0519
# valid cost: 10.162147
# ************************
#
#
# ************************
# iter: 345
# training cost: 632.1413
# valid cost: 8.461166
# ************************
#
#
# ************************
# iter: 346
# training cost: 632.87585
# valid cost: 10.071247
# ************************
#
#
# ************************
# iter: 347
# training cost: 632.92554
# valid cost: 8.686748
# ************************
#
#
# ************************
# iter: 348
# training cost: 630.61084
# valid cost: 9.61384
# ************************
#
#
# ************************
# iter: 349
# training cost: 631.8392
# valid cost: 8.705396
# ************************
#
#
# ************************
# iter: 350
# training cost: 630.24084
# valid cost: 9.887596
# ************************
#
#
# ************************
# iter: 351
# training cost: 630.29364
# valid cost: 8.292892
# ************************
#
#
# ************************
# iter: 352
# training cost: 630.9698
# valid cost: 10.703995
# ************************
#
#
# ************************
# iter: 353
# training cost: 631.1959
# valid cost: 8.292664
# ************************
#
#
# ************************
# iter: 354
# training cost: 633.64294
# valid cost: 11.165791
# ************************
#
#
# ************************
# iter: 355
# training cost: 632.042
# valid cost: 8.034659
# ************************
#
#
# ************************
# iter: 356
# training cost: 632.3075
# valid cost: 11.051424
# ************************
#
#
# ************************
# iter: 357
# training cost: 631.4183
# valid cost: 8.566848
# ************************
#
#
# ************************
# iter: 358
# training cost: 633.72424
# valid cost: 11.097307
# ************************
#
#
# ************************
# iter: 359
# training cost: 632.763
# valid cost: 8.497887
# ************************
#
#
# ************************
# iter: 360
# training cost: 633.55096
# valid cost: 10.8704
# ************************
#
#
# ************************
# iter: 361
# training cost: 633.5582
# valid cost: 8.910925
# ************************
#
#
# ************************
# iter: 362
# training cost: 631.1321
# valid cost: 9.848328
# ************************
#
#
# ************************
# iter: 363
# training cost: 630.7527
# valid cost: 9.515549
# ************************
#
#
# ************************
# iter: 364
# training cost: 632.0155
# valid cost: 9.4594755
# ************************

# %% [markdown]
# # LOAD DATA

# %%
# staticData = load_static_data()
# staticData = transform_to_grid_coordinates(staticData)
# mobileData = load_mobile_sensors()
# mobileData = transform_to_grid_coordinates(mobileData)
# allData = pd.concat([staticData, mobileData], ignore_index=True)
# setIds(staticData)
# setIds(allData)
# allData

with open("all_data_15_min_20_grid.txt", "rb") as fp:   # Unpickling
    all_data = pickle.load(fp)

# %%
all_data

# %% [markdown]
# # Model Functions

# %%
#TODO add params for activations, num layers, width of layers, optimizer, loss function, learning rate, batch size
def createStationaryModel():
    online_model = tf.keras.Sequential([
        layers.Dense(12, activation=tf.nn.relu, input_shape=[len(constants.CONTINUOUS_TRAINING_FEATURES)]),
        layers.Dense(12, activation=tf.nn.relu),
        layers.Dense(1)
    ])
    online_optimizer = tf.keras.optimizers.Adam(0.00001)

    online_model.compile(loss='mean_absolute_error',
        optimizer=online_optimizer,
        metrics=['mean_absolute_error', 'mean_squared_error'])
    
#     online_model_w_prev = tf.keras.Sequential([
#         layers.Dense(12, activation=tf.nn.relu, input_shape=[len(constants.CONTINUOUS_TRAINING_FEATURES_W_PREV)]),
#         layers.Dense(16, activation=tf.nn.relu),
# #         layers.Dense(16, activation=tf.nn.relu),
#         layers.Dense(1)
#     ])
#     online_w_prev_optimizer = tf.keras.optimizers.Adam(0.00001)

#     online_model_w_prev.compile(loss='mean_absolute_error',
#         optimizer=online_w_prev_optimizer,
#         metrics=['mean_absolute_error', 'mean_squared_error'])
    
    par = PassiveAggressiveRegressor(C=1, epsilon=0.1, loss='epsilon_insensitive', max_iter=100, random_state=0,tol=1e-3)
    
    return online_model, par

# %%
online_model, par_model = createStationaryModel()

# %% [markdown]
# # Train

# %%
def updateModels(data):
    label = data.pop('next_pm_2.5')
    X = data[constants.CONTINUOUS_TRAINING_FEATURES]
    label = np.array(label)
    
    online_model.fit(
        X, label, batch_size=len(data),
        epochs=200, verbose=0)

    par_model.partial_fit(X, label)
                
def trainNNs(train_data):
    class PrintDot(keras.callbacks.Callback):
        def on_epoch_end(self, epoch, logs):
            if epoch % 100 == 0: print('')
            print('.', end='')
                
    labels = []
    X = pd.DataFrame(columns = constants.CONTINUOUS_TRAINING_FEATURES)
    
    start = int(train_data['timestepContinuous'].min())
    end = int(train_data['timestepContinuous'].max())
    for i in range(start, end):
        cur_data = train_data[train_data['timestepContinuous'] == i]
        #Get list of all coords
        lat_coords = np.array(cur_data['lat_grid'])
        long_coords = np.array(cur_data['long_grid'])
                
        for x, y in zip(lat_coords, long_coords):
            x = int(x)
            y = int(y)
            
            #Check which coords have data next step
            if(grid_labels[i + 1][x][y] != None):
                #Append curData for coords that do have data next step
                new_input = cur_data[(cur_data['lat_grid'] == x) & (cur_data['long_grid'] == y)][constants.CONTINUOUS_TRAINING_FEATURES]
                X = pd.concat([X, new_input])
                #Append grid data to labels
                labels.append(grid_labels[i + 1][x][y])
        
    early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)

    par_model.fit(X, labels)

    history = online_model.fit(
        X, labels, batch_size=16,
        epochs=1000, verbose=0, validation_split = .2, callbacks=[ early_stop, PrintDot()])

    plot_history(history)
    hist = pd.DataFrame(history.history)
    display(hist)
    
def trainNNnn(trainData):
    
    class PrintDot(keras.callbacks.Callback):
        def on_epoch_end(self, epoch, logs):
            if epoch % 100 == 0: print('')
            print('.', end='')
                
    
        
    X = trainData[constants.CONTINUOUS_TRAINING_FEATURES]
    labels = trainData.pop('next_pm_2.5')
    early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)

    par_model.fit(X, labels)

    history = online_model.fit(
        X, labels, batch_size=8,
        epochs=1000, verbose=0, validation_split = .2, callbacks=[ early_stop, PrintDot()])

    plot_history(history)
    hist = pd.DataFrame(history.history)
    display(hist)
    
        
def plot_history(history):
    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch

    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Abs Error')
    plt.plot(hist['epoch'], hist['mean_absolute_error'],
           label='Train Error')
    plt.plot(hist['epoch'], hist['val_mean_absolute_error'],
           label = 'Val Error')
    plt.legend()

# %%
train = all_data[all_data['timestepContinuous'] <= 1450]
valid = all_data[(all_data['timestepContinuous'] > 1450)]

# %% [markdown]
# # Train Functions

# %%
# trainNNs(train)
trainNNnn(train)

# %%
with open("grid_labels.txt", "rb") as fp:   # Unpickling
    grid_labels = pickle.load(fp)

# %% [markdown]
# # Test Time Functions

# %%
def copy_model(model):
    batch_model = keras.models.clone_model(model)
    batch_model.build((None, len(constants.CONTINUOUS_TRAINING_FEATURES)))
    batch_model.compile(optimizer='adam', loss='mean_absolute_error')
    batch_model.set_weights(model.get_weights())
    
    return batch_model

def predictOneTimestep(data):
    online_pred_matrix = [[None for x in range(constants.GRID_SIZE)] for y in range(constants.GRID_SIZE)]
    batch_pred_matrix = [[None for x in range(constants.GRID_SIZE)] for y in range(constants.GRID_SIZE)]
    par_pred_matrix = [[None for x in range(constants.GRID_SIZE)] for y in range(constants.GRID_SIZE)]
    
    #get each datapoint in df and check coords and place in grid
    if (len(data) > 0):
        for index, row in data.iterrows():
            x = int(row['lat_grid'])
            y = int(row['long_grid'])
            columns = list(row.index)
                    
            online_pred, batch_pred, par_pred = predictOneDataPoint(pd.DataFrame(row).transpose())
            online_pred_matrix[x][y] = online_pred
            batch_pred_matrix[x][y] = batch_pred
            par_pred_matrix[x][y] = par_pred

    return online_pred_matrix, batch_pred_matrix, par_pred_matrix

def predictOneDataPoint(X):
    X = np.array(X[constants.CONTINUOUS_TRAINING_FEATURES])
    online_pred = online_model.predict(X)
    batch_pred = batch_model.predict(X)
    par_pred = par_model.predict(X)
    
    return (online_pred[0][0], batch_pred[0][0], par_pred[0])

def interpolate(pred_matrix):

    #PLACE CNN HERE
    return cnnModel.predict(pred_matrix, constants.GRID_SIZE)
#     data = np.array([[x, y, pred_matrix[x][y]] for x in range(constants.GRID_SIZE) for y in range(constants.GRID_SIZE) if pred_matrix[x][y] != None])
#     if(len(data) > 0):
#         ok = OrdinaryKriging(data[:,0], data[:,1], data[:,2], variogram_model='gaussian', verbose=False, enable_plotting=False)
#         gridx = np.arange(0.0, constants.GRID_SIZE, 1)
#         gridy = np.arange(0.0, constants.GRID_SIZE, 1)
#         z, ss = ok.execute('grid', gridx, gridy)
#         return z
#     else:
#         return pred_matrix
    
def get_valid_preds(timestep, online_pred_matrix, batch_pred_matrix, par_pred_matrix):
    labels = []
    online_preds = []
    batch_preds = []
    par_preds = []
    
    for x in range(constants.GRID_SIZE):
        for y in range(constants.GRID_SIZE):
            if(grid_labels[timestep + 1][x][y] != None):
                online_preds.append(online_pred_matrix[x][y])
                batch_preds.append(batch_pred_matrix[x][y])
                par_preds.append(par_pred_matrix[x][y])
                labels.append(grid_labels[timestep + 1][x][y])
    
    return (np.array(online_preds), np.array(batch_preds), par_preds, labels)
    

def getFullPredictions(data):
    online_predictions = []
    batch_predictions = []
    ensemble = []
    par_predictions = []
    all_labels = []
    
    flat_online_preds = []
    flat_batch_preds = []
    flat_par_preds = []
    flat_ensemble_preds = []
    
    for i in range(int(data['timestepContinuous'].min()), int(data['timestepContinuous'].max())):
#     for i in range(1522, 1550):
        print(i)
        newData = data[data['timestepContinuous'] == i]
        
        if(len(newData) > 0):
            online_pred_matrix, batch_pred_matrix, par_pred_matrix = predictOneTimestep(newData)

            int_online_pred_matrix = interpolate(online_pred_matrix)
            int_batch_pred_matrix = interpolate(batch_pred_matrix)
            int_par_pred_matrix = interpolate(par_pred_matrix)
            
            #Reshape to fit grid
            int_online_pred_matrix = np.array(int_online_pred_matrix).reshape(constants.GRID_SIZE,constants.GRID_SIZE)
            int_batch_pred_matrix = np.array(int_batch_pred_matrix).reshape(constants.GRID_SIZE,constants.GRID_SIZE)
            int_par_pred_matrix = np.array(int_par_pred_matrix).reshape(constants.GRID_SIZE,constants.GRID_SIZE)
            
            print(int_online_pred_matrix)
            online_pred, batch_pred, par_pred, labels = get_valid_preds(i, int_online_pred_matrix, int_batch_pred_matrix, int_par_pred_matrix)
            
            flat_online_preds.extend(online_pred)
            flat_batch_preds.extend(batch_pred)
            flat_par_preds.extend(par_pred)
            all_labels.extend(labels)
            
#             online_predictions.append(int_online_pred_matrix)
#             par_predictions.append(int_par_pred_matrix)
#             batch_predictions.append(int_batch_pred_matrix)

            
#             ensemble_pred_matrix = np.add((.5 * int_online_pred_matrix) + (.5 * int_batch_pred_matrix))
           
#             ensemble_pred = np.add((.5 * online_pred) + (.5 * batch_pred))

#             flat_ensemble_preds.append(ensemble_pred)

            updateModels(newData)
    return (flat_online_preds, flat_batch_preds, flat_par_preds, all_labels)

# %%
batch_model = copy_model(online_model)
online_preds, batch_predictions, par_preds, labels = getFullPredictions(valid)
print(mean_absolute_error(np.array(online_preds), np.array(labels)))
print(mean_absolute_error(batch_predictions, labels))
# print(mean_absolute_error(ensemble_preds, labels))
print(mean_absolute_error(par_preds, labels))

# %%
print(np.array(int_online_pred_matrix).shape)
ax = sns.heatmap(np.array(online_preds)[110])
ax.invert_yaxis()

# %%
for i in range(200, 250):
    plt.imshow(online_preds[i], cmap='hot', interpolation='nearest')
    plt.show()

# %%
osm_dir = "/Users/ryanegan/Documents/diss/"
filename = osm_dir + "prediction_sample_grid_" + str(constants.GRID_SIZE) + ".csv"
with open(filename, 'w') as csvfile:
    writer = csv.writer(csvfile, lineterminator='\n')
    writer.writerows(online_preds[300])

# %%
def plot_preds(preds, labels):
#     hist = pd.DataFrame(history.history)
#     hist['epoch'] = history.epoch

    x = range(len(preds))
    plt.figure()
    plt.xlabel('Data Point')
    plt.ylabel('PM 2.5')
    plt.plot(x, preds,
           label='Predictions')
    plt.plot(x, labels,
           label = 'True Value')
    plt.ylim([0,5])
    plt.xlim([0, 300])
    plt.legend()

    plt.show()

plot_preds(online_preds, labels)
