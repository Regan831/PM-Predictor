# %% [markdown]
# # Sensor Calibration

# %% [markdown]
# ### Calibration of six stationary and two mobile sensors during a period of colocation

# %%
##Adapted from Andrew Bates' code at https://github.com/specknet/airspeck-comparison/blob/master/6%20Airspeck%20S.ipynb
import os
from data_download import DataDownloader

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

from datetime import datetime
import time

from bokeh.io import show, output_notebook, output_file, reset_output
from bokeh.plotting import figure

from bokeh.models import DatetimeTickFormatter

# %%
start_date = 20180601
end_date = 20180615

uuids = ["02E5F77764B873DA",
        "200A7CED9D597407",
        "E5FD8C55EAA37555",
        "AA0E63CF5118F98F",
        "B61241EF668DBC2C",
        "E786F1568F65C296" ]

sids = ['XXG161', 'XXG162']

factors = [[1.0 ,        1.0 ,       1.0 , 1.    ,     1.            ],
 [2.0100042 , 1.54961648 ,1.5126218 , 1.00494929, 1.00478554],
 [1.59078671, 1.21618292, 1.19189916, 1.01233884, 0.9918236],
 [2.93987177 ,2.3760729 , 2.31180713, 0.98098509, 1.03301718],
 [2.75341775 ,2.34367823, 2.21772871, 0.98226178, 1.01829024],
 [8.11136564, 7.08428589, 7.04657879, 0.96830023, 1.03546691],
 [5.05004303, 4.86456945, 4.72626118, 1.16005363, 0.74392267],
 [5.09431241, 4.90857996, 4.6303786, 1.18617219, 0.7362692  ]]

def toTimestamp(date):
    date = datetime.strptime(date.split(".")[0], "%Y-%m-%d %H:%M:%S")
    return date

data_dir = "/Users/ryanegan/Documents/diss/projectZoe/data/"+str(start_date)+"-"+str(end_date)+"/"

if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %% [markdown]
# ## Download Data

# %%
#Download data
dataDownloader = DataDownloader()
dataDownloader.loadAirSpeckS(start_date, end_date, data_dir)
#Once this data is downloaded, it can be retrieved from: data_dir + "/" + str(uuid) + '.csv'

dataDownloader.loadAirSpeckP(start_date, end_date, sids, data_dir)
#Once this data is downloaded, it can be retrieved from: data_dir + "/" + str(sid) + '_' + str(date) + '.csv'
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta name="description" content="pyramid web application">
#     <meta name="author" content="Pylons Project">
#
#     <title>Daphne dashboard</title>
#
#     <!-- Bootstrap core CSS -->
#     <link href="//oss.maxcdn.com/libs/twitter-bootstrap/3.0.3/css/bootstrap.min.css" rel="stylesheet">
#
#     <!-- Custom styles for this scaffold -->
#     <link href="https://dashboard.specknet.uk/static/theme.css" rel="stylesheet">
#
#     <!-- Icons -->
#     <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.0.13/css/all.css" integrity="sha384-DNOHZ68U8hZfKXOrtjWvjxusGo9WQnrNx2sqG0tfsghAvtVlRW3tvkXWZh58N9jp" crossorigin="anonymous">
#
#     <!-- Highcharts -->
#     <script src="https://code.jquery.com/jquery-3.1.1.min.js"></script>
#     <script src="https://code.highcharts.com/stock/highstock.js"></script>
#     <script src="https://code.highcharts.com/stock/modules/exporting.js"></script>
#     <script src="https://code.highcharts.com/highcharts-more.js"></script>
#
#     <!-- HTML5 shim and Respond.js IE8 support of HTML5 elements and media queries -->
#     <!--[if lt IE 9]>
#     <script src="//oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"
#             integrity="sha384-0s5Pv64cNZJieYFkXYOTId2HMA2Lfb6q2nAcx2n0RTLUnCAoTTsS0nKEO27XyKcY"
#             crossorigin="anonymous"></script>
#     <script src="//oss.maxcdn.com/libs/respond.js/1.3.0/respond.min.js"
#             integrity="sha384-f1r2UzjsxZ9T4V1f2zBO/evUqSEOpeaUUZcMTz1Up63bl4ruYnFYeM+BxI4NhyI0"
#             crossorigin="anonymous"></script>
#     <![endif]-->
# </head>
#
# <body>
#
# <div class="header">
#     <nav class="navbar navbar-default" role="navigation">
#         <!-- Brand and toggle get grouped for better mobile display -->
#         <div class="navbar-header">
#             <a class="navbar-brand" rel="home" href="http://www.ed.ac.uk/" title="UoE">
#                 <img class="navbar-logos" height="50" src="https://dashboard.specknet.uk/static/uoe.png"></a>
#
#             <div class="navbar-brand title"><span class="title-text">AirRespeck Dashboard</span></div>
#
#             <a id="specknet-logo" class="navbar-brand" rel="home" href="http://www.specknet.uk/" title="Specknet">
#                 <img class="navbar-logos" height="50" src="https://dashboard.specknet.uk/static/specknet.png"></a>
#         </div>
#     </nav>
# </div>
#
# <div class="form-container">
#     <form action="https://dashboard.specknet.uk/" method="POST" id="load-overview-form">
#         <div class="form-row">
#             <div class="form-col-33">
#                 <label class="edittextlabel" for="subject_id">Subject ID</label>
#             </div>
#             <div class="form-col-33">
#                 <input type="text" id="sid" name="subject_id" placeholder="XXX001"
#                        value="">
#             </div>
#         </div>
#         <div class="form-row">
#             <div class="form-col-33"></div>
#             <div class="radiogroup_and_checkbox_container">
#                 <label class="checkbox_and_radio_label">
#                     <input id="all_data_checkbox" class="checkbox" type="checkbox" name="load_all_data">
#                     Load all data for subject
#                 </label>
#             </div>
#         </div>
#         <div id="date_container">
#             <div class="form-row">
#                 <div class="form-col-33">
#                     <label class="edittextlabel" for="date_from">Date FROM</label>
#                 </div>
#                 <div class="form-col-33">
#                     <input type="text" id="date_from" name="date_from" value="04.06.19">
#                 </div>
#                 <div class="form-col-33">
#                     <input type="text" id="time_from" name="time_from" value="00:00">
#                 </div>
#             </div>
#             <div class="form-row">
#                 <div class="form-col-33">
#                     <label class="edittextlabel" for="date_to">Date TO</label>
#                 </div>
#                 <div class="form-col-33">
#                     <input type="text" id="date_to" name="date_to" value="04.06.19">
#                 </div>
#                 <div class="form-col-33">
#                     <input type="text" id="time_to" name="time_to" value="23:59">
#                 </div>
#             </div>
#         </div>
#         <div class="form-row">
#             <div class="form-col-33"></div>
#             <div class="radiogroup_and_checkbox_container">
#                 <label class="checkbox_and_radio_label">
#                     <input type="radio" name="data_upload_radio_group" id="manual_upload_radio" value="manual"
#                            class="radio">
#                     Manually uploaded data
#                 </label>
#                 <label class="checkbox_and_radio_label">
#                     <input type="radio" name="data_upload_radio_group" id="automatic_upload_radio" value="automatic"
#                            class="radio">
#                     Automatically uploaded data
#                 </label>
#             </div>
#         </div>
#         <div class="form-row">
#             <div class="form-col-33"></div>
#             <input type="submit" name="form.submitted" value="Load subject overview" onclick="return checkInput();">
#         </div>
#     </form>
# </div>
# <div id="overview-graph-area"></div>
# <script>
#
#     // Validation of input
#     function checkInput() {
#         // Check subject ID
#         let entered_id = document.getElementById('sid').value;
#         if (!/^[A-Z0-9]{6}$/.test(entered_id)) {
#             alert("Subject ID has to be in format XXYZZZ, where XXY are letters and ZZZ digits");
#             return false;
#         }
#
#         // Check date if user did manual input
#         if (!document.getElementById("all_data_checkbox").checked) {
#             // Check date
#             let date_from = document.getElementById('date_from').value;
#             let date_to = document.getElementById('date_to').value;
#             let time_from = document.getElementById('time_from').value;
#             let time_to = document.getElementById('time_to').value;
#
#             if (!/^[0-9]{2}\.[0-9]{2}\.[0-9]{2}$/.test(date_from)) {
#                 alert("FROM date is not in the right format (DD.MM.YY)!");
#                 return false;
#             }
#             if (!/^[0-9]{2}\.[0-9]{2}\.[0-9]{2}$/.test(date_to)) {
#                 alert("TO date is not in the right format (DD.MM.YY)!");
#                 return false;
#             }
#
#             if (!/^[0-9]{2}:[0-9]{2}$/.test(time_from)) {
#                 alert("FROM time is not in the right format (00:00)!");
#                 return false;
#             }
#
#             if (!/^[0-9]{2}:[0-9]{2}$/.test(time_to)) {
#                 alert("TO time is not in the right format (00:00)!");
#                 return false;
#             }
#         }
#         return true;
#     }
#
#     if ("manual" === "manual") {
#         document.getElementById('manual_upload_radio').checked = true
#     } else {
#         document.getElementById('automatic_upload_radio').checked = true
#     }
#
#
#     let checkbox_all_data = document.getElementById("all_data_checkbox");
#
#     checkbox_all_data.onclick = function () {
#         if (checkbox_all_data.checked) {
#             $("#date_container :input").attr("disabled", true);
#         } else {
#             $("#date_container :input").attr("disabled", false);
#         }
#     };
#
#     // Click checkbox when it was checked before submission, and by default
#     if ("no" === "yes" || "no" === "no") {
#         checkbox_all_data.click();
#     }
#
#     if ("no" === "yes") {
#         document.getElementById('overview-graph-area').innerHTML =
#                 `
#         <div class="loader"></div>
#                 `;
#
#         // Create new image and dynamically replace once it's loaded
#         let downloadingImage = new Image();
#
#         downloadingImage.onload = function () {
#             document.getElementById('overview-graph-area').innerHTML =
#                     `
#             <img id="overview-device-icons" src="https://dashboard.specknet.uk/static/respeck_and_airspeck_icons.svg">
#             <img id="overview-graph" src="
#             ` + this.src +
#                     `"/>
#             <div id="overview-box">
#                 <div class="overview_box_title font-bold">Show dashboard</div>
#                 <div class="overview_box_column">
#                     <button class="box-first-button" id="dashboard_respeck_button" disabled><i class="fas fa-chart-line"></i>
#                     </button>
#                     <button class="box-second-button" id="dashboard_airspeck_button"><i class="far fa-map"></i>
#                     </button>
#                 </div>
#                 <div class="overview_box_column">
#                     <button class="box-third-button" id="dashboard_both_button"><i class="fas fa-chart-line"></i></button>
#                 </div>
#             </div>
#             <div id="overview-box">
#                 <div class="overview_box_title font-bold">Download reports</div>
#                 <div class="overview_box_column">
#                     <button class="box-first-button" id="report_respeck_button"><i class="fas fa-download"></i>
#                     </button>
#                     <button class="box-second-button" id="report_airspeck_button"><i class="fas fa-download"></i>
#                     </button>
#                 </div>
#                 <div class="overview_box_column">
#                     <button class="box-third-button" id="report_both_button"><i class="fas fa-download"></i></button>
#                 </div>
#             </div>
#             `;
#
#             /*
#             document.getElementById("dashboard_respeck_button").set = function () {
#                 let url = 'https://dashboard.specknet.uk/airspeckp_and_respeck////manual/h\')';
#                 window.open(url);
#             };*/
#
#             document.getElementById("dashboard_airspeck_button").onclick = function () {
#                 // Check if we're loading less than two hours
#                 if (parseDate('') - parseDate('') > (1000 * 60 * 60 * 2 + 1000)) {
#                     window.alert("Please select a timeframe of less than two hours to load the map!");
#                 } else {
#                     let url = 'https://dashboard.specknet.uk/airspeckp_map////manual';
#                     window.open(url);
#                 }
#             };
#
#             document.getElementById("dashboard_both_button").onclick = function () {
#                 let url = 'https://dashboard.specknet.uk/airspeckp_and_respeck////manual/h';
#                 window.open(url);
#             };
#
#             document.getElementById("report_respeck_button").onclick = function () {
#                 let url = 'https://dashboard.specknet.uk/download/respeck_report////manual/_respeck_report.png';
#                 window.open(url);
#             };
#
#             document.getElementById("report_airspeck_button").onclick = function () {
#                 let url = 'https://dashboard.specknet.uk/download/airspeck_report////manual/_airspeck_report.png';
#                 window.open(url);
#             };
#
#             document.getElementById("report_both_button").onclick = function () {
#                 let url = 'https://dashboard.specknet.uk/download/combined_report////manual/_report.png';
#                 window.open(url);
#             };
#
#         };
#         downloadingImage.src = 'https://dashboard.specknet.uk/subject_overview////manual/no'
#
#
#     }
#
#     function parseDate(ds) {
#         return new Date(ds.substring(0, 4), ds.substring(4, 6) - 1, ds.substring(6, 8), ds.substring(9, 11),
#                 ds.substring(11, 13));
#     }
#
#
# </script>
#
#
#
# <!-- Bootstrap core JavaScript
# ================================================== -->
# <!-- Placed at the end of the document so the pages load faster -->
# <script src="//oss.maxcdn.com/libs/jquery/1.10.2/jquery.min.js"
#         integrity="sha384-aBL3Lzi6c9LNDGvpHkZrrm3ZVsIwohDD7CDozL0pk8FwCrfmV7H9w8j3L7ikEv6h"
#         crossorigin="anonymous"></script>
# <script src="//oss.maxcdn.com/libs/twitter-bootstrap/3.0.3/js/bootstrap.min.js"
#         integrity="sha384-s1ITto93iSMDxlp/79qhWHi+LsIi9Gx6yL+cOKDuymvihkfol83TYbLbOw+W/wv4"
#         crossorigin="anonymous"></script>
# </body>
# </html>
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta name="description" content="pyramid web application">
#     <meta name="author" content="Pylons Project">
#
#     <title>Daphne dashboard</title>
#
#     <!-- Bootstrap core CSS -->
#     <link href="//oss.maxcdn.com/libs/twitter-bootstrap/3.0.3/css/bootstrap.min.css" rel="stylesheet">
#
#     <!-- Custom styles for this scaffold -->
#     <link href="https://dashboard.specknet.uk/static/theme.css" rel="stylesheet">
#
#     <!-- Icons -->
#     <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.0.13/css/all.css" integrity="sha384-DNOHZ68U8hZfKXOrtjWvjxusGo9WQnrNx2sqG0tfsghAvtVlRW3tvkXWZh58N9jp" crossorigin="anonymous">
#
#     <!-- Highcharts -->
#     <script src="https://code.jquery.com/jquery-3.1.1.min.js"></script>
#     <script src="https://code.highcharts.com/stock/highstock.js"></script>
#     <script src="https://code.highcharts.com/stock/modules/exporting.js"></script>
#     <script src="https://code.highcharts.com/highcharts-more.js"></script>
#
#     <!-- HTML5 shim and Respond.js IE8 support of HTML5 elements and media queries -->
#     <!--[if lt IE 9]>
#     <script src="//oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"
#             integrity="sha384-0s5Pv64cNZJieYFkXYOTId2HMA2Lfb6q2nAcx2n0RTLUnCAoTTsS0nKEO27XyKcY"
#             crossorigin="anonymous"></script>
#     <script src="//oss.maxcdn.com/libs/respond.js/1.3.0/respond.min.js"
#             integrity="sha384-f1r2UzjsxZ9T4V1f2zBO/evUqSEOpeaUUZcMTz1Up63bl4ruYnFYeM+BxI4NhyI0"
#             crossorigin="anonymous"></script>
#     <![endif]-->
# </head>
#
# <body>
#
# <div class="header">
#     <nav class="navbar navbar-default" role="navigation">
#         <!-- Brand and toggle get grouped for better mobile display -->
#         <div class="navbar-header">
#             <a class="navbar-brand" rel="home" href="http://www.ed.ac.uk/" title="UoE">
#                 <img class="navbar-logos" height="50" src="https://dashboard.specknet.uk/static/uoe.png"></a>
#
#             <div class="navbar-brand title"><span class="title-text">AirRespeck Dashboard</span></div>
#
#             <a id="specknet-logo" class="navbar-brand" rel="home" href="http://www.specknet.uk/" title="Specknet">
#                 <img class="navbar-logos" height="50" src="https://dashboard.specknet.uk/static/specknet.png"></a>
#         </div>
#     </nav>
# </div>
#
# <div class="form-container">
#     <form action="https://dashboard.specknet.uk/" method="POST" id="load-overview-form">
#         <div class="form-row">
#             <div class="form-col-33">
#                 <label class="edittextlabel" for="subject_id">Subject ID</label>
#             </div>
#             <div class="form-col-33">
#                 <input type="text" id="sid" name="subject_id" placeholder="XXX001"
#                        value="">
#             </div>
#         </div>
#         <div class="form-row">
#             <div class="form-col-33"></div>
#             <div class="radiogroup_and_checkbox_container">
#                 <label class="checkbox_and_radio_label">
#                     <input id="all_data_checkbox" class="checkbox" type="checkbox" name="load_all_data">
#                     Load all data for subject
#                 </label>
#             </div>
#         </div>
#         <div id="date_container">
#             <div class="form-row">
#                 <div class="form-col-33">
#                     <label class="edittextlabel" for="date_from">Date FROM</label>
#                 </div>
#                 <div class="form-col-33">
#                     <input type="text" id="date_from" name="date_from" value="04.06.19">
#                 </div>
#                 <div class="form-col-33">
#                     <input type="text" id="time_from" name="time_from" value="00:00">
#                 </div>
#             </div>
#             <div class="form-row">
#                 <div class="form-col-33">
#                     <label class="edittextlabel" for="date_to">Date TO</label>
#                 </div>
#                 <div class="form-col-33">
#                     <input type="text" id="date_to" name="date_to" value="04.06.19">
#                 </div>
#                 <div class="form-col-33">
#                     <input type="text" id="time_to" name="time_to" value="23:59">
#                 </div>
#             </div>
#         </div>
#         <div class="form-row">
#             <div class="form-col-33"></div>
#             <div class="radiogroup_and_checkbox_container">
#                 <label class="checkbox_and_radio_label">
#                     <input type="radio" name="data_upload_radio_group" id="manual_upload_radio" value="manual"
#                            class="radio">
#                     Manually uploaded data
#                 </label>
#                 <label class="checkbox_and_radio_label">
#                     <input type="radio" name="data_upload_radio_group" id="automatic_upload_radio" value="automatic"
#                            class="radio">
#                     Automatically uploaded data
#                 </label>
#             </div>
#         </div>
#         <div class="form-row">
#             <div class="form-col-33"></div>
#             <input type="submit" name="form.submitted" value="Load subject overview" onclick="return checkInput();">
#         </div>
#     </form>
# </div>
# <div id="overview-graph-area"></div>
# <script>
#
#     // Validation of input
#     function checkInput() {
#         // Check subject ID
#         let entered_id = document.getElementById('sid').value;
#         if (!/^[A-Z0-9]{6}$/.test(entered_id)) {
#             alert("Subject ID has to be in format XXYZZZ, where XXY are letters and ZZZ digits");
#             return false;
#         }
#
#         // Check date if user did manual input
#         if (!document.getElementById("all_data_checkbox").checked) {
#             // Check date
#             let date_from = document.getElementById('date_from').value;
#             let date_to = document.getElementById('date_to').value;
#             let time_from = document.getElementById('time_from').value;
#             let time_to = document.getElementById('time_to').value;
#
#             if (!/^[0-9]{2}\.[0-9]{2}\.[0-9]{2}$/.test(date_from)) {
#                 alert("FROM date is not in the right format (DD.MM.YY)!");
#                 return false;
#             }
#             if (!/^[0-9]{2}\.[0-9]{2}\.[0-9]{2}$/.test(date_to)) {
#                 alert("TO date is not in the right format (DD.MM.YY)!");
#                 return false;
#             }
#
#             if (!/^[0-9]{2}:[0-9]{2}$/.test(time_from)) {
#                 alert("FROM time is not in the right format (00:00)!");
#                 return false;
#             }
#
#             if (!/^[0-9]{2}:[0-9]{2}$/.test(time_to)) {
#                 alert("TO time is not in the right format (00:00)!");
#                 return false;
#             }
#         }
#         return true;
#     }
#
#     if ("manual" === "manual") {
#         document.getElementById('manual_upload_radio').checked = true
#     } else {
#         document.getElementById('automatic_upload_radio').checked = true
#     }
#
#
#     let checkbox_all_data = document.getElementById("all_data_checkbox");
#
#     checkbox_all_data.onclick = function () {
#         if (checkbox_all_data.checked) {
#             $("#date_container :input").attr("disabled", true);
#         } else {
#             $("#date_container :input").attr("disabled", false);
#         }
#     };
#
#     // Click checkbox when it was checked before submission, and by default
#     if ("no" === "yes" || "no" === "no") {
#         checkbox_all_data.click();
#     }
#
#     if ("no" === "yes") {
#         document.getElementById('overview-graph-area').innerHTML =
#                 `
#         <div class="loader"></div>
#                 `;
#
#         // Create new image and dynamically replace once it's loaded
#         let downloadingImage = new Image();
#
#         downloadingImage.onload = function () {
#             document.getElementById('overview-graph-area').innerHTML =
#                     `
#             <img id="overview-device-icons" src="https://dashboard.specknet.uk/static/respeck_and_airspeck_icons.svg">
#             <img id="overview-graph" src="
#             ` + this.src +
#                     `"/>
#             <div id="overview-box">
#                 <div class="overview_box_title font-bold">Show dashboard</div>
#                 <div class="overview_box_column">
#                     <button class="box-first-button" id="dashboard_respeck_button" disabled><i class="fas fa-chart-line"></i>
#                     </button>
#                     <button class="box-second-button" id="dashboard_airspeck_button"><i class="far fa-map"></i>
#                     </button>
#                 </div>
#                 <div class="overview_box_column">
#                     <button class="box-third-button" id="dashboard_both_button"><i class="fas fa-chart-line"></i></button>
#                 </div>
#             </div>
#             <div id="overview-box">
#                 <div class="overview_box_title font-bold">Download reports</div>
#                 <div class="overview_box_column">
#                     <button class="box-first-button" id="report_respeck_button"><i class="fas fa-download"></i>
#                     </button>
#                     <button class="box-second-button" id="report_airspeck_button"><i class="fas fa-download"></i>
#                     </button>
#                 </div>
#                 <div class="overview_box_column">
#                     <button class="box-third-button" id="report_both_button"><i class="fas fa-download"></i></button>
#                 </div>
#             </div>
#             `;
#
#             /*
#             document.getElementById("dashboard_respeck_button").set = function () {
#                 let url = 'https://dashboard.specknet.uk/airspeckp_and_respeck////manual/h\')';
#                 window.open(url);
#             };*/
#
#             document.getElementById("dashboard_airspeck_button").onclick = function () {
#                 // Check if we're loading less than two hours
#                 if (parseDate('') - parseDate('') > (1000 * 60 * 60 * 2 + 1000)) {
#                     window.alert("Please select a timeframe of less than two hours to load the map!");
#                 } else {
#                     let url = 'https://dashboard.specknet.uk/airspeckp_map////manual';
#                     window.open(url);
#                 }
#             };
#
#             document.getElementById("dashboard_both_button").onclick = function () {
#                 let url = 'https://dashboard.specknet.uk/airspeckp_and_respeck////manual/h';
#                 window.open(url);
#             };
#
#             document.getElementById("report_respeck_button").onclick = function () {
#                 let url = 'https://dashboard.specknet.uk/download/respeck_report////manual/_respeck_report.png';
#                 window.open(url);
#             };
#
#             document.getElementById("report_airspeck_button").onclick = function () {
#                 let url = 'https://dashboard.specknet.uk/download/airspeck_report////manual/_airspeck_report.png';
#                 window.open(url);
#             };
#
#             document.getElementById("report_both_button").onclick = function () {
#                 let url = 'https://dashboard.specknet.uk/download/combined_report////manual/_report.png';
#                 window.open(url);
#             };
#
#         };
#         downloadingImage.src = 'https://dashboard.specknet.uk/subject_overview////manual/no'
#
#
#     }
#
#     function parseDate(ds) {
#         return new Date(ds.substring(0, 4), ds.substring(4, 6) - 1, ds.substring(6, 8), ds.substring(9, 11),
#                 ds.substring(11, 13));
#     }
#
#
# </script>
#
#
#
# <!-- Bootstrap core JavaScript
# ================================================== -->
# <!-- Placed at the end of the document so the pages load faster -->
# <script src="//oss.maxcdn.com/libs/jquery/1.10.2/jquery.min.js"
#         integrity="sha384-aBL3Lzi6c9LNDGvpHkZrrm3ZVsIwohDD7CDozL0pk8FwCrfmV7H9w8j3L7ikEv6h"
#         crossorigin="anonymous"></script>
# <script src="//oss.maxcdn.com/libs/twitter-bootstrap/3.0.3/js/bootstrap.min.js"
#         integrity="sha384-s1ITto93iSMDxlp/79qhWHi+LsIi9Gx6yL+cOKDuymvihkfol83TYbLbOw+W/wv4"
#         crossorigin="anonymous"></script>
# </body>
# </html>
#
#
# https://dashboard.specknet.uk/downloadPersonalAirspeck/XXG161/20180601/20180615
# https://dashboard.specknet.uk/downloadPersonalAirspeck/XXG162/20180601/20180615

# %% [markdown]
# ## Read Static CSV

# %%
sdata = []
#sdates = []
for i in range(len(uuids)):
    sdata.append(pd.read_csv(data_dir + uuids[i]+".csv"))
    absoluteTime = []
    for j in range(len(sdata[i])):
        absoluteTime.append(toTimestamp(sdata[i]["Timestamp"].values[j]))
    sdata[i]["absoluteTime"] = absoluteTime

# %% [markdown]
# ## Read Mobile CSV

# %%
pdata = []
for i in range(len(sids)):
    pdata_by_day = []
    for j in range(20180605, 20180607): 
        #Only plot these two days because they cover the colocation period
        pdata_by_day.append(pd.read_csv(data_dir + "/" + str(sids[i]) + '_' + str(j) + '.csv'))
        
    pdata_by_sid = pd.concat(pdata_by_day)
    pdata.append(pdata_by_sid)

    absoluteTime = []
    for k in range(len(pdata[i])):
        absoluteTime.append(toTimestamp(pdata[i]["Timestamp"].values[k]))
    pdata[i]["absoluteTime"] = absoluteTime

# %% [markdown]
# ## Plot Calibrated Data

# %%
plot_names = ["PM1","PM2.5", "PM10", "temperature", "humidity"]
CB_color_cycle = ['#377eb8', '#ff7f00', '#4daf4a', '#f781bf', '#a65628', '#984ea3', '#999999', '#e41a1c', '#dede00']

for pidx, plot_name in enumerate(plot_names):
    reset_output()
    output_file(data_dir + "/{}.html".format("ave_" + plot_name + "_" + str(start_date)))

    fig = figure(plot_width=1200, plot_height=600,x_axis_type="datetime", title="Average " + plot_name + " (" + str(start_date) + ")")    

    for i in range(len(sids)):
        # Plot uncalibrated data 
        #fig.line(pdata[i]["absoluteTime"].values, pdata[i][plot_name].values, legend='Personal: ' + sids[i], color=CB_color_cycle[len(uuids) + i])
        
        #Plot calibrated data
        fig.line(pdata[i]["absoluteTime"].values, pdata[i][plot_name].values / factors[i + len(uuids)][pidx], legend='Personal: ' + sids[i], color=CB_color_cycle[len(uuids) + i])

    for i in range(len(uuids)):
        # Plot uncalibrated data
        #fig.line(sdata[i]["absoluteTime"].values, sdata[i][plot_name].values, legend='Static: ' + uuids[i], color=CB_color_cycle[i])
        
        #Plot calibrated data
        fig.line(sdata[i]["absoluteTime"].values, sdata[i][plot_name].values / factors[i][pidx], legend='Static: ' + uuids[i], color=CB_color_cycle[i])

            
    fig.legend.location = "top_left"
    show(fig)

# %% [markdown]
# ## Calibration calculations

# %%
#From  1528202000.0
#To    1528275000.0
# They were all happily colocated

def getColocatedSlice(data, ids):
    calibrationData = []
    for i in range(len(ids)):
        #print(data[i].shape)
        condition1 = data[i]["absoluteTime"] > 1528202100.0
        condition2 = data[i]["absoluteTime"] < 1528275000.0
        condition = condition1 & condition2
        calibrationData.append(data[i][condition])
        print(calibrationData[i].shape)
        
    return calibrationData

sCalibrationData = getColocatedSlice(sdata, uuids)
pCalibrationData = getColocatedSlice(pdata, sids)
print(sCalibrationData[0].head(5))
print(sCalibrationData[0].tail(5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-b0638093e4eb> in <module>
#      15     return calibrationData
#      16
# ---> 17 sCalibrationData = getColocatedSlice(sdata, uuids)
#      18 pCalibrationData = getColocatedSlice(pdata, sids)
#      19 print(sCalibrationData[0].head(5))
#
# <ipython-input-20-b0638093e4eb> in getColocatedSlice(data, ids)
#       7     for i in range(len(ids)):
#       8         #print(data[i].shape)
# ----> 9         condition1 = data[i]["absoluteTime"] > 1528202100.0
#      10         condition2 = data[i]["absoluteTime"] < 1528275000.0
#      11         condition = condition1 & condition2
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1714
#    1715             res_values = dispatch_to_index_op(op, self, other,
# -> 1716                                               pd.DatetimeIndex)
#    1717
#    1718             return self._constructor(res_values, index=self.index,
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in dispatch_to_index_op(op, left, right, index_class)
#    1189         left_idx = left_idx._shallow_copy(freq=None)
#    1190     try:
# -> 1191         result = op(left_idx, right)
#    1192     except NullFrequencyError:
#    1193         # DatetimeIndex and TimedeltaIndex with freq == None raise ValueError
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/datetimelike.py in wrapper(self, other)
#     115                 other = other._values
#     116
# --> 117             result = op(self._data, maybe_unwrap_index(other))
#     118             return result
#     119
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py in wrapper(self, other)
#     152                 result.fill(nat_result)
#     153         elif lib.is_scalar(other) or np.ndim(other) == 0:
# --> 154             return ops.invalid_comparison(self, other, op)
#     155         elif len(other) != len(self):
#     156             raise ValueError("Lengths must match")
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in invalid_comparison(left, right, op)
#    1056     else:
#    1057         raise TypeError("Invalid comparison between dtype={dtype} and {typ}"
# -> 1058                         .format(dtype=left.dtype, typ=type(right).__name__))
#    1059     return res_values
#    1060
#
# TypeError: Invalid comparison between dtype=datetime64[ns] and float

# %%
#Downsample pdata to every 5 mins
pDownsampledData = []
pCalibrationCopy = pCalibrationData

for i in range(len(sids)):
    newP = pCalibrationCopy[i].set_index(["Timestamp"])
    newP.index = pd.to_datetime(newP.index)
    #NOTE THIS IS DELETING LATITUDE IN PDATA[0] POSSIBLY BECAUSE OF A NAN
    pDownsampledData.append(newP.resample('5Min').mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d1f7a80e506f> in <module>
#       1 #Downsample pdata to every 5 mins
#       2 pDownsampledData = []
# ----> 3 pCalibrationCopy = pCalibrationData
#       4
#       5 for i in range(len(sids)):
#
# NameError: name 'pCalibrationData' is not defined

# %%
PM_strs = ["PM1","PM2.5", "PM10", "temperature", "humidity"]
factors = np.empty((8,5))
for i in range(len(uuids)):
    for indx, PM_str in enumerate(PM_strs):
        data = sCalibrationData
        reference = sCalibrationData[0][PM_str].values
        reference = reference[~np.isnan(reference)]
        current = sCalibrationData[i][PM_str].values
        current = current[~np.isnan(current)]
        factor_array = current / reference
        factor = factor_array.mean()
        print("Sensor ID " + uuids[i] + " " + PM_str + " factor: " + str(factor))
        sCalibrationData[i][PM_str] /= factor
        factors[i][indx] = factor

for i in range(len(sids)):
    for indx, PM_str in enumerate(PM_strs):
        data = sCalibrationData
        reference = sCalibrationData[0][PM_str].values
        reference = reference[~np.isnan(reference)]
        current = pDownsampledData[i][PM_str].values
        current = current[~np.isnan(current)]
        factor_array = current / reference
        factor = factor_array.mean()
        print("Sensor ID " + sids[i] + " " + PM_str + " factor: " + str(factor))
        pDownsampledData[i][PM_str] /= factor
        factors[len(uuids) + i][indx] = factor
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-1e17adbee4ca> in <module>
#       3 for i in range(len(uuids)):
#       4     for indx, PM_str in enumerate(PM_strs):
# ----> 5         data = sCalibrationData
#       6         reference = sCalibrationData[0][PM_str].values
#       7         reference = reference[~np.isnan(reference)]
#
# NameError: name 'sCalibrationData' is not defined
